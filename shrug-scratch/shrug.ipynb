# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import janitor
import json
from tqdm.notebook import tqdm

import warnings
warnings.filterwarnings('ignore')

from utilities.utils import get_fulldata
from indicate import transliterate
# Out:
# 2023-05-06 18:21:58.249386: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-06 18:21:58.292889: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-06 18:21:58.293985: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-06 18:21:59.032395: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## SHRUG

# %%
gdf_state = gpd.read_file("geometries_shrug-v1.5.samosa-open-polygons-gpkg/state.gpkg")
gdf_state.info()
bihar_state_id = gdf_state.set_index("state_name").at["Bihar", "pc11_state_id"]
gdf_state
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pc11_state_id  35 non-null     object
#  1   state_name     35 non-null     object
#  2   geometry       35 non-null     geometry
# dtypes: geometry(1), object(2)
# memory usage: 968.0+ bytes
#    pc11_state_id                   state_name
# 0             01            Jammu and Kashmir  \
# 1             02             Himachal Pradesh
# 2             03                       Punjab
# 3             04                   Chandigarh
# 4             05                  Uttarakhand
# 5             06                      Haryana
# 6             07                 NCT Of Delhi
# 7             08                    Rajasthan
# 8             09                Uttar Pradesh
# 9             10                        Bihar
# 10            11                       Sikkim
# 11            12            Arunachal Pradesh
# 12            13                     Nagaland
# 13            14                      Manipur
# 14            15                      Mizoram
# 15            16                      Tripura
# 16            17                    Meghalaya
# 17            18                        Assam
# 18            19                  West Bengal
# 19            20                    Jharkhand
# 20            21                       Odisha
# 21            22                 Chhattisgarh
# 22            23               Madhya Pradesh
# 23            24                      Gujarat
# 24            25                Daman and Diu
# 25            26       Dadra and Nagar Haveli
# 26            27                  Maharashtra
# 27            28               Andhra Pradesh
# 28            29                    Karnataka
# 29            30                          Goa
# 30            31                  Lakshadweep
# 31            32                       Kerala
# 32            33                   Tamil Nadu
# 33            34                   Puducherry
# 34            35  Andaman and Nicobar Islands
#
#                                              geometry
# 0   POLYGON ((77.95837 35.48178, 77.96405 35.48433...
# 1   POLYGON ((76.80943 33.23872, 76.81593 33.23535...
# 2   POLYGON ((75.83876 32.52156, 75.83898 32.52128...
# 3   POLYGON ((76.79191 30.77115, 76.79229 30.77118...
# 4   POLYGON ((79.22439 31.34099, 79.22624 31.33888...
# 5   POLYGON ((76.84307 30.88633, 76.84365 30.88618...
# 6   POLYGON ((77.07688 28.88184, 77.07801 28.88149...
# 7   POLYGON ((73.90898 30.05334, 73.90437 30.05000...
# 8   MULTIPOLYGON (((79.36095 25.13890, 79.36217 25...
# 9   MULTIPOLYGON (((84.51370 24.25774, 84.51182 24...
# 10  POLYGON ((88.65147 28.09304, 88.65270 28.09111...
# 11  POLYGON ((96.11495 29.39999, 96.14150 29.36881...
# 12  POLYGON ((95.19597 26.99497, 95.19551 26.99432...
# 13  POLYGON ((94.57290 25.69122, 94.57351 25.68996...
# 14  POLYGON ((92.76760 24.51982, 92.76935 24.51554...
# 15  POLYGON ((92.17048 24.53087, 92.17477 24.52727...
# 16  POLYGON ((91.87533 26.08687, 91.87467 26.08240...
# 17  MULTIPOLYGON (((95.83399 27.97633, 95.83474 27...
# 18  MULTIPOLYGON (((89.13722 21.58363, 89.13528 21...
# 19  MULTIPOLYGON (((87.58306 25.33173, 87.58304 25...
# 20  MULTIPOLYGON (((84.32964 18.77430, 84.32837 18...
# 21  POLYGON ((83.34240 24.09431, 83.34712 24.09354...
# 22  MULTIPOLYGON (((74.17872 22.39110, 74.17660 22...
# 23  MULTIPOLYGON (((73.00949 20.23278, 73.01035 20...
# 24  MULTIPOLYGON (((72.83954 20.41098, 72.83959 20...
# 25  MULTIPOLYGON (((73.11651 20.31271, 73.11440 20...
# 26  MULTIPOLYGON (((73.65097 15.74617, 73.65074 15...
# 27  POLYGON ((78.34272 19.88310, 78.34640 19.88256...
# 28  MULTIPOLYGON (((74.08745 14.79268, 74.08778 14...
# 29  MULTIPOLYGON (((74.11488 14.75685, 74.11516 14...
# 30  MULTIPOLYGON (((73.07303 8.32989, 73.07357 8.3...
# 31  POLYGON ((74.99777 12.78738, 74.99890 12.78715...
# 32  MULTIPOLYGON (((78.21360 8.83204, 78.21265 8.8...
# 33  MULTIPOLYGON (((75.54115 11.70230, 75.54089 11...
# 34  MULTIPOLYGON (((93.84339 7.22376, 93.84418 7.2...

# %%
gdf_districts = (
    gpd.read_file("geometries_shrug-v1.5.samosa-open-polygons-gpkg/district.gpkg")
    .query(f"pc11_state_id=='{bihar_state_id}'")
    .assign(district_name=lambda df: df["district_name"].str.lower())
    .reset_index(drop=True)
)
gdf_districts.info()
gdf_districts
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pc11_state_id     38 non-null     object
#  1   pc11_district_id  38 non-null     object
#  2   district_name     38 non-null     object
#  3   geometry          38 non-null     geometry
# dtypes: geometry(1), object(3)
# memory usage: 1.3+ KB
#    pc11_state_id pc11_district_id       district_name
# 0             10              203  pashchim champaran  \
# 1             10              204     purba champaran
# 2             10              205             sheohar
# 3             10              206           sitamarhi
# 4             10              207           madhubani
# 5             10              208              supaul
# 6             10              209              araria
# 7             10              210          kishanganj
# 8             10              211              purnia
# 9             10              212             katihar
# 10            10              213           madhepura
# 11            10              214             saharsa
# 12            10              215           darbhanga
# 13            10              216         muzaffarpur
# 14            10              217           gopalganj
# 15            10              218               siwan
# 16            10              219               saran
# 17            10              220            vaishali
# 18            10              221          samastipur
# 19            10              222           begusarai
# 20            10              223            khagaria
# 21            10              224           bhagalpur
# 22            10              225               banka
# 23            10              226              munger
# 24            10              227          lakhisarai
# 25            10              228          sheikhpura
# 26            10              229             nalanda
# 27            10              230               patna
# 28            10              231             bhojpur
# 29            10              232               buxar
# 30            10              233     kaimur (bhabua)
# 31            10              234              rohtas
# 32            10              235          aurangabad
# 33            10              236                gaya
# 34            10              237              nawada
# 35            10              238               jamui
# 36            10              239           jehanabad
# 37            10              240               arwal
#
#                                              geometry
# 0   POLYGON ((84.12469 27.51105, 84.12628 27.51085...
# 1   POLYGON ((84.83041 27.01919, 84.83128 27.01916...
# 2   POLYGON ((85.32738 26.65375, 85.32803 26.65304...
# 3   POLYGON ((85.66200 26.84586, 85.66625 26.84437...
# 4   POLYGON ((86.06059 26.65650, 86.06645 26.65505...
# 5   POLYGON ((87.05293 26.55341, 87.05334 26.55334...
# 6   POLYGON ((87.06975 26.56275, 87.06950 26.55288...
# 7   MULTIPOLYGON (((87.84553 25.98449, 87.84566 25...
# 8   POLYGON ((87.71802 26.11298, 87.71835 26.11297...
# 9   POLYGON ((87.82502 25.88259, 87.82553 25.88247...
# 10  POLYGON ((86.74821 26.11318, 86.74886 26.11224...
# 11  POLYGON ((86.43670 26.06372, 86.43714 26.06352...
# 12  POLYGON ((85.71936 26.44483, 85.72029 26.44397...
# 13  POLYGON ((85.58092 26.39322, 85.58173 26.39088...
# 14  POLYGON ((84.11410 26.63336, 84.11439 26.63334...
# 15  POLYGON ((84.40285 26.36415, 84.40395 26.36356...
# 16  POLYGON ((84.87313 26.21165, 84.87369 26.21163...
# 17  POLYGON ((85.25131 26.00914, 85.25170 26.00909...
# 18  POLYGON ((85.71753 26.08220, 85.71798 26.08212...
# 19  POLYGON ((86.12759 25.76362, 86.12795 25.76341...
# 20  POLYGON ((86.40191 25.73625, 86.40280 25.73601...
# 21  POLYGON ((87.09845 25.49145, 87.09792 25.48972...
# 22  POLYGON ((86.73864 25.12136, 86.73858 25.12072...
# 23  POLYGON ((86.56461 25.49128, 86.56803 25.49122...
# 24  POLYGON ((86.11032 25.31469, 86.11215 25.31451...
# 25  POLYGON ((85.73666 25.27670, 85.73670 25.27618...
# 26  POLYGON ((85.41586 25.44830, 85.41675 25.44783...
# 27  POLYGON ((84.99418 25.73146, 84.99470 25.73145...
# 28  POLYGON ((84.69442 25.75236, 84.69464 25.75111...
# 29  MULTIPOLYGON (((84.14912 25.72990, 84.14822 25...
# 30  MULTIPOLYGON (((83.33928 25.18009, 83.33889 25...
# 31  POLYGON ((84.05529 25.37326, 84.05681 25.37270...
# 32  POLYGON ((84.46874 25.09176, 84.46984 25.09157...
# 33  MULTIPOLYGON (((84.51472 24.25770, 84.51427 24...
# 34  POLYGON ((85.68174 25.10746, 85.68207 25.10744...
# 35  POLYGON ((86.40714 25.09627, 86.40500 25.09240...
# 36  POLYGON ((85.00455 25.31710, 85.00495 25.31684...
# 37  POLYGON ((84.70671 25.31483, 84.70909 25.31016...

# %%
# Divisions?
gdf_subdistricts = (
    gpd.read_file("geometries_shrug-v1.5.samosa-open-polygons-gpkg/subdistrict.gpkg")
    .query(f"pc11_state_id=='{bihar_state_id}'")
    .assign(subdistrict_name=lambda df: df["subdistrict_name"].str.lower())
    .reset_index(drop=True)
)
gdf_subdistricts.info()
gdf_subdistricts.head(5)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 534 entries, 0 to 533
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pc11_state_id        534 non-null    object
#  1   pc11_district_id     534 non-null    object
#  2   pc11_subdistrict_id  534 non-null    object
#  3   subdistrict_name     534 non-null    object
#  4   geometry             534 non-null    geometry
# dtypes: geometry(1), object(4)
# memory usage: 21.0+ KB
#   pc11_state_id pc11_district_id pc11_subdistrict_id subdistrict_name
# 0            10              203               01013           sidhaw  \
# 1            10              203               01014         ramnagar
# 2            10              203               01015          gaunaha
# 3            10              203               01016        mainatanr
# 4            10              203               01017     narkatiaganj
#
#                                             geometry
# 0  POLYGON ((83.94735 27.44297, 83.94897 27.44205...
# 1  POLYGON ((84.12469 27.51105, 84.12628 27.51085...
# 2  POLYGON ((84.38576 27.37299, 84.39084 27.36994...
# 3  POLYGON ((84.65097 27.29101, 84.65572 27.28294...
# 4  POLYGON ((84.58513 27.19071, 84.58565 27.19002...

# %%
gdf_villages = (
    gpd.read_file("geometries_shrug-v1.5.samosa-open-polygons-gpkg/village.gpkg")
    .query(f"pc11_state_id=='{bihar_state_id}'")
    .assign(town_village_name=lambda df: df["town_village_name"].str.lower())
    .reset_index(drop=True)
)
gdf_villages.info()
gdf_villages.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 45107 entries, 0 to 45106
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   pc11_state_id         45107 non-null  object
#  1   pc11_district_id      45107 non-null  object
#  2   pc11_subdistrict_id   45107 non-null  object
#  3   pc11_town_village_id  45107 non-null  object
#  4   town_village_name     45072 non-null  object
#  5   geometry              45107 non-null  geometry
# dtypes: geometry(1), object(5)
# memory usage: 2.1+ MB
#   pc11_state_id pc11_district_id pc11_subdistrict_id pc11_town_village_id
# 0            10              203               01013               215989  \
# 1            10              203               01013               215990
# 2            10              203               01013               215991
# 3            10              203               01013               215992
# 4            10              203               01013               215993
#
#   town_village_name                                           geometry
# 0          kalapani  POLYGON ((83.95195 27.44241, 83.95057 27.44029...
# 1       bhaisalotan  POLYGON ((83.94735 27.44297, 83.94446 27.44172...
# 2            tharhi  POLYGON ((83.86745 27.43616, 83.87093 27.43540...
# 3             pipra  POLYGON ((83.90969 27.40805, 83.90759 27.40606...
# 4          kotaraha  POLYGON ((83.91060 27.39674, 83.90982 27.39623...

# %% [markdown]
# ## Divisions (subdistricts?): Land records
#
# * https://github.com/soodoku/land/blob/main/scripts/00_summary_basic_bihar_land_record.ipynb

# %%
fp_divisions = "divisions.csv"
if False:
    # Get divisions
    df_divisions = (
        get_fulldata(**{'usecols': ["division"]})
        .drop_duplicates(ignore_index=True)
        .assign(eng=np.nan)
    )
    # Transliterate
    for ix, row in tqdm(df_divisions.iterrows()):
        df_divisions.at[ix, "eng"] = transliterate.hindi2english(row["division"])
        
    df_divisions.to_csv(fp_divisions, index=False)
    
df_divisions = pd.read_csv(fp_divisions)
df_divisions.head(3)
# Out:
#        division              eng
# 0        वैशाली         vaishali
# 1  पटेढ़ी बेलसर  patedhi beluser
# 2        लालगंज          lalganj

# %%
df_divisions[df_divisions.duplicated("eng", keep=False)]
# Out:
#           division         eng
# 83       संग्रमपुर  sangrampur
# 106        बाराहाट     barahat
# 177           बरहट     barahat
# 268       सा0 कमाल         NaN
# 276  चे0 बरियारपुर         NaN
# 366        बगहा -1         NaN
# 450     संग्रामपुर  sangrampur

# %%
# Try merge with SHRUG
df_divisions = (
    df_divisions
    .dropna(subset=["eng"])
    .drop_duplicates("eng")
    .merge(gdf_subdistricts, how="outer", left_on="eng", right_on="subdistrict_name", validate="1:m", indicator=True)
)
df_divisions
# Out:
#          division              eng pc11_state_id pc11_district_id
# 0          वैशाली         vaishali            10              220  \
# 1    पटेढ़ी बेलसर  patedhi beluser           NaN              NaN
# 2          लालगंज          lalganj            10              220
# 3        भगवानपुर       bhagwanpur            10              220
# 4        भगवानपुर       bhagwanpur            10              222
# ..            ...              ...           ...              ...
# 811           NaN              NaN            10              239
# 812           NaN              NaN            10              239
# 813           NaN              NaN            10              239
# 814           NaN              NaN            10              240
# 815           NaN              NaN            10              240
#
#     pc11_subdistrict_id           subdistrict_name
# 0                 01268                   vaishali  \
# 1                   NaN                        NaN
# 2                 01270                    lalganj
# 3                 01271                 bhagwanpur
# 4                 01308                 bhagwanpur
# ..                  ...                        ...
# 811               01537                       kako
# 812               01538                  modanganj
# 813               01540                 makhdumpur
# 814               01542                      arwal
# 815               01545  sonbhadra banshi suryapur
#
#                                               geometry      _merge
# 0    POLYGON ((85.17616 26.00890, 85.17655 26.00858...        both
# 1                                                 None   left_only
# 2    POLYGON ((85.27043 25.91443, 85.26983 25.91342...        both
# 3    POLYGON ((85.28554 25.93287, 85.28608 25.93210...        both
# 4    POLYGON ((85.97766 25.62317, 85.97795 25.62281...        both
# ..                                                 ...         ...
# 811  POLYGON ((85.09374 25.28850, 85.09469 25.28781...  right_only
# 812  POLYGON ((85.14576 25.31181, 85.14654 25.31180...  right_only
# 813  POLYGON ((85.07797 25.15016, 85.07815 25.14854...  right_only
# 814  POLYGON ((84.70671 25.31483, 84.70909 25.31016...  right_only
# 815  POLYGON ((84.74671 25.15270, 84.74924 25.15170...  right_only
#
# [816 rows x 8 columns]

# %%
df_divisions.query("_merge=='both'")
# Out:
#      division         eng pc11_state_id pc11_district_id pc11_subdistrict_id
# 0      वैशाली    vaishali            10              220               01268  \
# 2      लालगंज     lalganj            10              220               01270
# 3    भगवानपुर  bhagwanpur            10              220               01271
# 4    भगवानपुर  bhagwanpur            10              222               01308
# 5    भगवानपुर  bhagwanpur            10              233               01455
# ..        ...         ...           ...              ...                 ...
# 503      औराई       aurai            10              216               01207
# 504      कटरा       katra            10              216               01208
# 505     काँटी       kanti            10              216               01204
# 508  साहेबगंज   sahebganj            10              216               01199
# 510     सरैया     saraiya            10              216               01202
#
#     subdistrict_name                                           geometry _merge
# 0           vaishali  POLYGON ((85.17616 26.00890, 85.17655 26.00858...   both
# 2            lalganj  POLYGON ((85.27043 25.91443, 85.26983 25.91342...   both
# 3         bhagwanpur  POLYGON ((85.28554 25.93287, 85.28608 25.93210...   both
# 4         bhagwanpur  POLYGON ((85.97766 25.62317, 85.97795 25.62281...   both
# 5         bhagwanpur  POLYGON ((83.62819 25.01638, 83.62923 25.01636...   both
# ..               ...                                                ...    ...
# 503            aurai  POLYGON ((85.58092 26.39322, 85.58173 26.39088...   both
# 504            katra  POLYGON ((85.65221 26.32562, 85.65257 26.32386...   both
# 505            kanti  MULTIPOLYGON (((85.38662 26.14974, 85.38624 26...   both
# 508        sahebganj  POLYGON ((85.01314 26.32546, 85.01443 26.32402...   both
# 510          saraiya  POLYGON ((85.13151 26.16455, 85.13193 26.16455...   both
#
# [229 rows x 8 columns]

# %%
df_divisions.query("_merge=='left_only'")
# Out:
#          division              eng pc11_state_id pc11_district_id
# 1    पटेढ़ी बेलसर  patedhi beluser           NaN              NaN  \
# 7         विदुपुर          vidupur           NaN              NaN
# 8         राधोपुर         radhopur           NaN              NaN
# 12      चेहरा कलॉ     chehra kalau           NaN              NaN
# 13       राजापाकर        rajapakar           NaN              NaN
# ..            ...              ...           ...              ...
# 500         बंदरा          bandara           NaN              NaN
# 501        बोचहाँ         bochahan           NaN              NaN
# 506          पारु             paru           NaN              NaN
# 507       मोतीपुर          motipur           NaN              NaN
# 509        कुढ्नी           kudhni           NaN              NaN
#
#     pc11_subdistrict_id subdistrict_name geometry     _merge
# 1                   NaN              NaN     None  left_only
# 7                   NaN              NaN     None  left_only
# 8                   NaN              NaN     None  left_only
# 12                  NaN              NaN     None  left_only
# 13                  NaN              NaN     None  left_only
# ..                  ...              ...      ...        ...
# 500                 NaN              NaN     None  left_only
# 501                 NaN              NaN     None  left_only
# 506                 NaN              NaN     None  left_only
# 507                 NaN              NaN     None  left_only
# 509                 NaN              NaN     None  left_only
#
# [282 rows x 8 columns]

# %%
df_divisions.query("_merge=='right_only'")
# Out:
#     division  eng pc11_state_id pc11_district_id pc11_subdistrict_id
# 511      NaN  NaN            10              203               01013  \
# 512      NaN  NaN            10              203               01014
# 513      NaN  NaN            10              203               01016
# 514      NaN  NaN            10              203               01017
# 515      NaN  NaN            10              203               01018
# ..       ...  ...           ...              ...                 ...
# 811      NaN  NaN            10              239               01537
# 812      NaN  NaN            10              239               01538
# 813      NaN  NaN            10              239               01540
# 814      NaN  NaN            10              240               01542
# 815      NaN  NaN            10              240               01545
#
#               subdistrict_name
# 511                     sidhaw  \
# 512                   ramnagar
# 513                  mainatanr
# 514               narkatiaganj
# 515                    lauriya
# ..                         ...
# 811                       kako
# 812                  modanganj
# 813                 makhdumpur
# 814                      arwal
# 815  sonbhadra banshi suryapur
#
#                                               geometry      _merge
# 511  POLYGON ((83.94735 27.44297, 83.94897 27.44205...  right_only
# 512  POLYGON ((84.12469 27.51105, 84.12628 27.51085...  right_only
# 513  POLYGON ((84.65097 27.29101, 84.65572 27.28294...  right_only
# 514  POLYGON ((84.58513 27.19071, 84.58565 27.19002...  right_only
# 515  POLYGON ((84.37649 27.06930, 84.37713 27.06922...  right_only
# ..                                                 ...         ...
# 811  POLYGON ((85.09374 25.28850, 85.09469 25.28781...  right_only
# 812  POLYGON ((85.14576 25.31181, 85.14654 25.31180...  right_only
# 813  POLYGON ((85.07797 25.15016, 85.07815 25.14854...  right_only
# 814  POLYGON ((84.70671 25.31483, 84.70909 25.31016...  right_only
# 815  POLYGON ((84.74671 25.15270, 84.74924 25.15170...  right_only
#
# [305 rows x 8 columns]

# %% [markdown]
# ## Districts: Land records

# %%
fp_districts = "districts.csv"
if False:
    # Get district
    df_districts = (
        get_fulldata(**{'usecols': ["district"]})
        .drop_duplicates(ignore_index=True)
        .assign(eng=np.nan)
    )
    # Transliterate
    for ix, row in tqdm(df_districts.iterrows()):
        df_districts.at[ix, "eng"] = transliterate.hindi2english(row["district"])
        
    df_districts.to_csv(fp_districts, index=False)
    
df_districts = pd.read_csv(fp_districts)
df_districts.head(3)
# Out:
#   district       eng
# 0   वैशाली  vaishali
# 1      गया      gaya
# 2   रोहतास    rohtas

# %%
assert len(df_districts) == len(gdf_districts)

# %%
# Try merge with SHRUG
df_districts = (
    df_districts
#     .dropna(subset=["eng"])
#     .drop_duplicates("eng")
    .merge(gdf_districts, how="outer", left_on="eng", right_on="district_name", validate="1:1", indicator=True)
    .sort_values("_merge")
    .reset_index(drop=True)
    .rename_column("district", "bihar_lr_district")
    .rename_column("eng", "bihar_lr_district_eng")
    .rename_column("district_name", "shrug_district")
)
df_districts
# Out:
#    bihar_lr_district bihar_lr_district_eng pc11_state_id pc11_district_id
# 0          पूर्णियॉं        purniyaaayaaon           NaN              NaN  \
# 1             खगड़िया              khagriya           NaN              NaN
# 2            सीतामढ़ी             sitamadhi           NaN              NaN
# 3              कैमूर                 camor           NaN              NaN
# 4     पूर्वी चम्पारण       purvi champaran           NaN              NaN
# 5            किशनगंज            kishenganj           NaN              NaN
# 6               अरवल                araval           NaN              NaN
# 7           बेगुसराए             begusaray           NaN              NaN
# 8         मुज़फ्फरपुर             muzfarpur           NaN              NaN
# 9              नवादा                navada           NaN              NaN
# 10          जहानाबाद             jahanabad           NaN              NaN
# 11           शेखपुरा             shekhpura           NaN              NaN
# 12             सिवान                 sivan           NaN              NaN
# 13             शिवहर              shivahar           NaN              NaN
# 14             बक्सर               bucksre           NaN              NaN
# 15               NaN                   NaN            10              216
# 16               NaN                   NaN            10              206
# 17               NaN                   NaN            10              205
# 18               NaN                   NaN            10              204
# 19               NaN                   NaN            10              218
# 20               NaN                   NaN            10              222
# 21               NaN                   NaN            10              223
# 22               NaN                   NaN            10              228
# 23               NaN                   NaN            10              232
# 24               NaN                   NaN            10              233
# 25               NaN                   NaN            10              237
# 26               NaN                   NaN            10              211
# 27               NaN                   NaN            10              210
# 28               NaN                   NaN            10              240
# 29               NaN                   NaN            10              239
# 30     पश्चिम चंपारण    pashchim champaran            10              203
# 31               गया                  gaya            10              236
# 32            रोहतास                rohtas            10              234
# 33         समस्तीपुर            samastipur            10              221
# 34            मुंगेर                munger            10              226
# 35            अररिया                araria            10              209
# 36             बांका                 banka            10              225
# 37             सुपौल                supaul            10              208
# 38           भागलपुर             bhagalpur            10              224
# 39            नालंदा               nalanda            10              229
# 40              जमुई                 jamui            10              238
# 41             सहरसा               saharsa            10              214
# 42          गोपालगंज             gopalganj            10              217
# 43            दरभंगा             darbhanga            10              215
# 44              पटना                 patna            10              230
# 45           मधेपुरा             madhepura            10              213
# 46          औरंगाबाद            aurangabad            10              235
# 47              सारण                 saran            10              219
# 48            कटिहार               katihar            10              212
# 49           लखीसराय            lakhisarai            10              227
# 50            भोजपुर               bhojpur            10              231
# 51            मधुबनी             madhubani            10              207
# 52            वैशाली              vaishali            10              220
#
#         shrug_district                                           geometry
# 0                  NaN                                               None  \
# 1                  NaN                                               None
# 2                  NaN                                               None
# 3                  NaN                                               None
# 4                  NaN                                               None
# 5                  NaN                                               None
# 6                  NaN                                               None
# 7                  NaN                                               None
# 8                  NaN                                               None
# 9                  NaN                                               None
# 10                 NaN                                               None
# 11                 NaN                                               None
# 12                 NaN                                               None
# 13                 NaN                                               None
# 14                 NaN                                               None
# 15         muzaffarpur  POLYGON ((85.58092 26.39322, 85.58173 26.39088...
# 16           sitamarhi  POLYGON ((85.66200 26.84586, 85.66625 26.84437...
# 17             sheohar  POLYGON ((85.32738 26.65375, 85.32803 26.65304...
# 18     purba champaran  POLYGON ((84.83041 27.01919, 84.83128 27.01916...
# 19               siwan  POLYGON ((84.40285 26.36415, 84.40395 26.36356...
# 20           begusarai  POLYGON ((86.12759 25.76362, 86.12795 25.76341...
# 21            khagaria  POLYGON ((86.40191 25.73625, 86.40280 25.73601...
# 22          sheikhpura  POLYGON ((85.73666 25.27670, 85.73670 25.27618...
# 23               buxar  MULTIPOLYGON (((84.14912 25.72990, 84.14822 25...
# 24     kaimur (bhabua)  MULTIPOLYGON (((83.33928 25.18009, 83.33889 25...
# 25              nawada  POLYGON ((85.68174 25.10746, 85.68207 25.10744...
# 26              purnia  POLYGON ((87.71802 26.11298, 87.71835 26.11297...
# 27          kishanganj  MULTIPOLYGON (((87.84553 25.98449, 87.84566 25...
# 28               arwal  POLYGON ((84.70671 25.31483, 84.70909 25.31016...
# 29           jehanabad  POLYGON ((85.00455 25.31710, 85.00495 25.31684...
# 30  pashchim champaran  POLYGON ((84.12469 27.51105, 84.12628 27.51085...
# 31                gaya  MULTIPOLYGON (((84.51472 24.25770, 84.51427 24...
# 32              rohtas  POLYGON ((84.05529 25.37326, 84.05681 25.37270...
# 33          samastipur  POLYGON ((85.71753 26.08220, 85.71798 26.08212...
# 34              munger  POLYGON ((86.56461 25.49128, 86.56803 25.49122...
# 35              araria  POLYGON ((87.06975 26.56275, 87.06950 26.55288...
# 36               banka  POLYGON ((86.73864 25.12136, 86.73858 25.12072...
# 37              supaul  POLYGON ((87.05293 26.55341, 87.05334 26.55334...
# 38           bhagalpur  POLYGON ((87.09845 25.49145, 87.09792 25.48972...
# 39             nalanda  POLYGON ((85.41586 25.44830, 85.41675 25.44783...
# 40               jamui  POLYGON ((86.40714 25.09627, 86.40500 25.09240...
# 41             saharsa  POLYGON ((86.43670 26.06372, 86.43714 26.06352...
# 42           gopalganj  POLYGON ((84.11410 26.63336, 84.11439 26.63334...
# 43           darbhanga  POLYGON ((85.71936 26.44483, 85.72029 26.44397...
# 44               patna  POLYGON ((84.99418 25.73146, 84.99470 25.73145...
# 45           madhepura  POLYGON ((86.74821 26.11318, 86.74886 26.11224...
# 46          aurangabad  POLYGON ((84.46874 25.09176, 84.46984 25.09157...
# 47               saran  POLYGON ((84.87313 26.21165, 84.87369 26.21163...
# 48             katihar  POLYGON ((87.82502 25.88259, 87.82553 25.88247...
# 49          lakhisarai  POLYGON ((86.11032 25.31469, 86.11215 25.31451...
# 50             bhojpur  POLYGON ((84.69442 25.75236, 84.69464 25.75111...
# 51           madhubani  POLYGON ((86.06059 26.65650, 86.06645 26.65505...
# 52            vaishali  POLYGON ((85.25131 26.00914, 85.25170 26.00909...
#
#         _merge
# 0    left_only
# 1    left_only
# 2    left_only
# 3    left_only
# 4    left_only
# 5    left_only
# 6    left_only
# 7    left_only
# 8    left_only
# 9    left_only
# 10   left_only
# 11   left_only
# 12   left_only
# 13   left_only
# 14   left_only
# 15  right_only
# 16  right_only
# 17  right_only
# 18  right_only
# 19  right_only
# 20  right_only
# 21  right_only
# 22  right_only
# 23  right_only
# 24  right_only
# 25  right_only
# 26  right_only
# 27  right_only
# 28  right_only
# 29  right_only
# 30        both
# 31        both
# 32        both
# 33        both
# 34        both
# 35        both
# 36        both
# 37        both
# 38        both
# 39        both
# 40        both
# 41        both
# 42        both
# 43        both
# 44        both
# 45        both
# 46        both
# 47        both
# 48        both
# 49        both
# 50        both
# 51        both
# 52        both

# %%
# Show successful merges
(df_districts
 .sort_values("_merge")
 .query("_merge=='both'")
 .remove_columns(["pc11_state_id", "geometry"])
 .reset_index(drop=True)
)
# Out:
#    bihar_lr_district bihar_lr_district_eng pc11_district_id
# 0             दरभंगा             darbhanga              215  \
# 1               पटना                 patna              230
# 2            मधेपुरा             madhepura              213
# 3             कटिहार               katihar              212
# 4               सारण                 saran              219
# 5           गोपालगंज             gopalganj              217
# 6            लखीसराय            lakhisarai              227
# 7             भोजपुर               bhojpur              231
# 8           औरंगाबाद            aurangabad              235
# 9              सहरसा               saharsa              214
# 10             सुपौल                supaul              208
# 11            नालंदा               nalanda              229
# 12           भागलपुर             bhagalpur              224
# 13             बांका                 banka              225
# 14            अररिया                araria              209
# 15            मुंगेर                munger              226
# 16         समस्तीपुर            samastipur              221
# 17            रोहतास                rohtas              234
# 18               गया                  gaya              236
# 19     पश्चिम चंपारण    pashchim champaran              203
# 20            मधुबनी             madhubani              207
# 21              जमुई                 jamui              238
# 22            वैशाली              vaishali              220
#
#         shrug_district _merge
# 0            darbhanga   both
# 1                patna   both
# 2            madhepura   both
# 3              katihar   both
# 4                saran   both
# 5            gopalganj   both
# 6           lakhisarai   both
# 7              bhojpur   both
# 8           aurangabad   both
# 9              saharsa   both
# 10              supaul   both
# 11             nalanda   both
# 12           bhagalpur   both
# 13               banka   both
# 14              araria   both
# 15              munger   both
# 16          samastipur   both
# 17              rohtas   both
# 18                gaya   both
# 19  pashchim champaran   both
# 20           madhubani   both
# 21               jamui   both
# 22            vaishali   both

# %%
# Show only districts found in Bihar land record
(df_districts
 .sort_values("_merge")
 .query("_merge=='left_only'")
 .remove_columns(["pc11_state_id", "geometry"])
 .reset_index(drop=True)
)
# Out:
#    bihar_lr_district bihar_lr_district_eng pc11_district_id shrug_district
# 0          पूर्णियॉं        purniyaaayaaon              NaN            NaN  \
# 1              बक्सर               bucksre              NaN            NaN
# 2              शिवहर              shivahar              NaN            NaN
# 3              सिवान                 sivan              NaN            NaN
# 4            शेखपुरा             shekhpura              NaN            NaN
# 5              नवादा                navada              NaN            NaN
# 6         मुज़फ्फरपुर             muzfarpur              NaN            NaN
# 7           जहानाबाद             jahanabad              NaN            NaN
# 8               अरवल                araval              NaN            NaN
# 9            किशनगंज            kishenganj              NaN            NaN
# 10    पूर्वी चम्पारण       purvi champaran              NaN            NaN
# 11             कैमूर                 camor              NaN            NaN
# 12           सीतामढ़ी             sitamadhi              NaN            NaN
# 13            खगड़िया              khagriya              NaN            NaN
# 14          बेगुसराए             begusaray              NaN            NaN
#
#        _merge
# 0   left_only
# 1   left_only
# 2   left_only
# 3   left_only
# 4   left_only
# 5   left_only
# 6   left_only
# 7   left_only
# 8   left_only
# 9   left_only
# 10  left_only
# 11  left_only
# 12  left_only
# 13  left_only
# 14  left_only

# %%
# Show only districts found in SHRUG
(df_districts
 .sort_values("_merge")
 .query("_merge=='right_only'")
 .remove_columns(["pc11_state_id", "geometry"])
 .reset_index(drop=True)
)
# Out:
#    bihar_lr_district bihar_lr_district_eng pc11_district_id   shrug_district
# 0                NaN                   NaN              232            buxar  \
# 1                NaN                   NaN              239        jehanabad
# 2                NaN                   NaN              240            arwal
# 3                NaN                   NaN              210       kishanganj
# 4                NaN                   NaN              237           nawada
# 5                NaN                   NaN              233  kaimur (bhabua)
# 6                NaN                   NaN              228       sheikhpura
# 7                NaN                   NaN              211           purnia
# 8                NaN                   NaN              222        begusarai
# 9                NaN                   NaN              218            siwan
# 10               NaN                   NaN              204  purba champaran
# 11               NaN                   NaN              223         khagaria
# 12               NaN                   NaN              205          sheohar
# 13               NaN                   NaN              206        sitamarhi
# 14               NaN                   NaN              216      muzaffarpur
#
#         _merge
# 0   right_only
# 1   right_only
# 2   right_only
# 3   right_only
# 4   right_only
# 5   right_only
# 6   right_only
# 7   right_only
# 8   right_only
# 9   right_only
# 10  right_only
# 11  right_only
# 12  right_only
# 13  right_only
# 14  right_only

# %% [markdown]
# ## Residence (villages?): Land Records

# %%
fp_residences = "residences.csv"
if True:
    # Get district
    df_residences = (
        get_fulldata(**{'usecols': ["district"]})
        .drop_duplicates(ignore_index=True)
        .assign(eng=np.nan)
    )
    # Transliterate
    for ix, row in tqdm(df_residences.iterrows()):
        df_residences.at[ix, "eng"] = transliterate.hindi2english(row["district"])
        
    df_residences.to_csv(fp_residences, index=False)
    
df_residences = pd.read_csv(fp_residences)
df_residences.head(3)
# Out:
# 0it [00:00, ?it/s]
# 2023-05-06 18:26:35.571296: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 18:26:35.571611: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
#   district       eng
# 0   वैशाली  vaishali
# 1      गया      gaya
# 2   रोहतास    rohtas
