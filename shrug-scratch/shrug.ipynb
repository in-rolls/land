# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import janitor
import json
from tqdm.notebook import tqdm

from utilities.utils import get_fulldata
from indicate import transliterate

# %% [markdown]
# ## SHRUG

# %%
gdf_state = gpd.read_file("geometries_shrug-v1.5.samosa-open-polygons-gpkg/state.gpkg")
gdf_state.info()
bihar_state_id = gdf_state.set_index("state_name").at["Bihar", "pc11_state_id"]
gdf_state
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pc11_state_id  35 non-null     object
#  1   state_name     35 non-null     object
#  2   geometry       35 non-null     geometry
# dtypes: geometry(1), object(2)
# memory usage: 968.0+ bytes
#    pc11_state_id                   state_name
# 0             01            Jammu and Kashmir  \
# 1             02             Himachal Pradesh
# 2             03                       Punjab
# 3             04                   Chandigarh
# 4             05                  Uttarakhand
# 5             06                      Haryana
# 6             07                 NCT Of Delhi
# 7             08                    Rajasthan
# 8             09                Uttar Pradesh
# 9             10                        Bihar
# 10            11                       Sikkim
# 11            12            Arunachal Pradesh
# 12            13                     Nagaland
# 13            14                      Manipur
# 14            15                      Mizoram
# 15            16                      Tripura
# 16            17                    Meghalaya
# 17            18                        Assam
# 18            19                  West Bengal
# 19            20                    Jharkhand
# 20            21                       Odisha
# 21            22                 Chhattisgarh
# 22            23               Madhya Pradesh
# 23            24                      Gujarat
# 24            25                Daman and Diu
# 25            26       Dadra and Nagar Haveli
# 26            27                  Maharashtra
# 27            28               Andhra Pradesh
# 28            29                    Karnataka
# 29            30                          Goa
# 30            31                  Lakshadweep
# 31            32                       Kerala
# 32            33                   Tamil Nadu
# 33            34                   Puducherry
# 34            35  Andaman and Nicobar Islands
#
#                                              geometry
# 0   POLYGON ((77.95837 35.48178, 77.96405 35.48433...
# 1   POLYGON ((76.80943 33.23872, 76.81593 33.23535...
# 2   POLYGON ((75.83876 32.52156, 75.83898 32.52128...
# 3   POLYGON ((76.79191 30.77115, 76.79229 30.77118...
# 4   POLYGON ((79.22439 31.34099, 79.22624 31.33888...
# 5   POLYGON ((76.84307 30.88633, 76.84365 30.88618...
# 6   POLYGON ((77.07688 28.88184, 77.07801 28.88149...
# 7   POLYGON ((73.90898 30.05334, 73.90437 30.05000...
# 8   MULTIPOLYGON (((79.36095 25.13890, 79.36217 25...
# 9   MULTIPOLYGON (((84.51370 24.25774, 84.51182 24...
# 10  POLYGON ((88.65147 28.09304, 88.65270 28.09111...
# 11  POLYGON ((96.11495 29.39999, 96.14150 29.36881...
# 12  POLYGON ((95.19597 26.99497, 95.19551 26.99432...
# 13  POLYGON ((94.57290 25.69122, 94.57351 25.68996...
# 14  POLYGON ((92.76760 24.51982, 92.76935 24.51554...
# 15  POLYGON ((92.17048 24.53087, 92.17477 24.52727...
# 16  POLYGON ((91.87533 26.08687, 91.87467 26.08240...
# 17  MULTIPOLYGON (((95.83399 27.97633, 95.83474 27...
# 18  MULTIPOLYGON (((89.13722 21.58363, 89.13528 21...
# 19  MULTIPOLYGON (((87.58306 25.33173, 87.58304 25...
# 20  MULTIPOLYGON (((84.32964 18.77430, 84.32837 18...
# 21  POLYGON ((83.34240 24.09431, 83.34712 24.09354...
# 22  MULTIPOLYGON (((74.17872 22.39110, 74.17660 22...
# 23  MULTIPOLYGON (((73.00949 20.23278, 73.01035 20...
# 24  MULTIPOLYGON (((72.83954 20.41098, 72.83959 20...
# 25  MULTIPOLYGON (((73.11651 20.31271, 73.11440 20...
# 26  MULTIPOLYGON (((73.65097 15.74617, 73.65074 15...
# 27  POLYGON ((78.34272 19.88310, 78.34640 19.88256...
# 28  MULTIPOLYGON (((74.08745 14.79268, 74.08778 14...
# 29  MULTIPOLYGON (((74.11488 14.75685, 74.11516 14...
# 30  MULTIPOLYGON (((73.07303 8.32989, 73.07357 8.3...
# 31  POLYGON ((74.99777 12.78738, 74.99890 12.78715...
# 32  MULTIPOLYGON (((78.21360 8.83204, 78.21265 8.8...
# 33  MULTIPOLYGON (((75.54115 11.70230, 75.54089 11...
# 34  MULTIPOLYGON (((93.84339 7.22376, 93.84418 7.2...

# %%
gdf_districts = (
    gpd.read_file("geometries_shrug-v1.5.samosa-open-polygons-gpkg/district.gpkg")
    .query(f"pc11_state_id=='{bihar_state_id}'")
    .assign(district_name=lambda df: df["district_name"].str.lower())
    .reset_index(drop=True)
)
gdf_districts.info()
gdf_districts
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 38 entries, 304 to 341
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pc11_state_id     38 non-null     object
#  1   pc11_district_id  38 non-null     object
#  2   district_name     38 non-null     object
#  3   geometry          38 non-null     geometry
# dtypes: geometry(1), object(3)
# memory usage: 1.5+ KB
#     pc11_state_id pc11_district_id       district_name
# 304            10              203  pashchim champaran  \
# 305            10              204     purba champaran
# 306            10              205             sheohar
# 307            10              206           sitamarhi
# 308            10              207           madhubani
# 309            10              208              supaul
# 310            10              209              araria
# 311            10              210          kishanganj
# 312            10              211              purnia
# 313            10              212             katihar
# 314            10              213           madhepura
# 315            10              214             saharsa
# 316            10              215           darbhanga
# 317            10              216         muzaffarpur
# 318            10              217           gopalganj
# 319            10              218               siwan
# 320            10              219               saran
# 321            10              220            vaishali
# 322            10              221          samastipur
# 323            10              222           begusarai
# 324            10              223            khagaria
# 325            10              224           bhagalpur
# 326            10              225               banka
# 327            10              226              munger
# 328            10              227          lakhisarai
# 329            10              228          sheikhpura
# 330            10              229             nalanda
# 331            10              230               patna
# 332            10              231             bhojpur
# 333            10              232               buxar
# 334            10              233     kaimur (bhabua)
# 335            10              234              rohtas
# 336            10              235          aurangabad
# 337            10              236                gaya
# 338            10              237              nawada
# 339            10              238               jamui
# 340            10              239           jehanabad
# 341            10              240               arwal
#
#                                               geometry
# 304  POLYGON ((84.12469 27.51105, 84.12628 27.51085...
# 305  POLYGON ((84.83041 27.01919, 84.83128 27.01916...
# 306  POLYGON ((85.32738 26.65375, 85.32803 26.65304...
# 307  POLYGON ((85.66200 26.84586, 85.66625 26.84437...
# 308  POLYGON ((86.06059 26.65650, 86.06645 26.65505...
# 309  POLYGON ((87.05293 26.55341, 87.05334 26.55334...
# 310  POLYGON ((87.06975 26.56275, 87.06950 26.55288...
# 311  MULTIPOLYGON (((87.84553 25.98449, 87.84566 25...
# 312  POLYGON ((87.71802 26.11298, 87.71835 26.11297...
# 313  POLYGON ((87.82502 25.88259, 87.82553 25.88247...
# 314  POLYGON ((86.74821 26.11318, 86.74886 26.11224...
# 315  POLYGON ((86.43670 26.06372, 86.43714 26.06352...
# 316  POLYGON ((85.71936 26.44483, 85.72029 26.44397...
# 317  POLYGON ((85.58092 26.39322, 85.58173 26.39088...
# 318  POLYGON ((84.11410 26.63336, 84.11439 26.63334...
# 319  POLYGON ((84.40285 26.36415, 84.40395 26.36356...
# 320  POLYGON ((84.87313 26.21165, 84.87369 26.21163...
# 321  POLYGON ((85.25131 26.00914, 85.25170 26.00909...
# 322  POLYGON ((85.71753 26.08220, 85.71798 26.08212...
# 323  POLYGON ((86.12759 25.76362, 86.12795 25.76341...
# 324  POLYGON ((86.40191 25.73625, 86.40280 25.73601...
# 325  POLYGON ((87.09845 25.49145, 87.09792 25.48972...
# 326  POLYGON ((86.73864 25.12136, 86.73858 25.12072...
# 327  POLYGON ((86.56461 25.49128, 86.56803 25.49122...
# 328  POLYGON ((86.11032 25.31469, 86.11215 25.31451...
# 329  POLYGON ((85.73666 25.27670, 85.73670 25.27618...
# 330  POLYGON ((85.41586 25.44830, 85.41675 25.44783...
# 331  POLYGON ((84.99418 25.73146, 84.99470 25.73145...
# 332  POLYGON ((84.69442 25.75236, 84.69464 25.75111...
# 333  MULTIPOLYGON (((84.14912 25.72990, 84.14822 25...
# 334  MULTIPOLYGON (((83.33928 25.18009, 83.33889 25...
# 335  POLYGON ((84.05529 25.37326, 84.05681 25.37270...
# 336  POLYGON ((84.46874 25.09176, 84.46984 25.09157...
# 337  MULTIPOLYGON (((84.51472 24.25770, 84.51427 24...
# 338  POLYGON ((85.68174 25.10746, 85.68207 25.10744...
# 339  POLYGON ((86.40714 25.09627, 86.40500 25.09240...
# 340  POLYGON ((85.00455 25.31710, 85.00495 25.31684...
# 341  POLYGON ((84.70671 25.31483, 84.70909 25.31016...

# %%
# Divisions?
gdf_subdistricts = (
    gpd.read_file("geometries_shrug-v1.5.samosa-open-polygons-gpkg/subdistrict.gpkg")
    .query(f"pc11_state_id=='{bihar_state_id}'")
    .assign(subdistrict_name=lambda df: df["subdistrict_name"].str.lower())
    .reset_index(drop=True)
)
gdf_subdistricts.info()
gdf_subdistricts.head(5)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 534 entries, 2124 to 2657
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pc11_state_id        534 non-null    object
#  1   pc11_district_id     534 non-null    object
#  2   pc11_subdistrict_id  534 non-null    object
#  3   subdistrict_name     534 non-null    object
#  4   geometry             534 non-null    geometry
# dtypes: geometry(1), object(4)
# memory usage: 25.0+ KB
#      pc11_state_id pc11_district_id pc11_subdistrict_id subdistrict_name
# 2124            10              203               01013           sidhaw  \
# 2125            10              203               01014         ramnagar
# 2126            10              203               01015          gaunaha
# 2127            10              203               01016        mainatanr
# 2128            10              203               01017     narkatiaganj
#
#                                                geometry
# 2124  POLYGON ((83.94735 27.44297, 83.94897 27.44205...
# 2125  POLYGON ((84.12469 27.51105, 84.12628 27.51085...
# 2126  POLYGON ((84.38576 27.37299, 84.39084 27.36994...
# 2127  POLYGON ((84.65097 27.29101, 84.65572 27.28294...
# 2128  POLYGON ((84.58513 27.19071, 84.58565 27.19002...

# %%
gdf_villages = (
    gpd.read_file("geometries_shrug-v1.5.samosa-open-polygons-gpkg/village.gpkg")
    .query(f"pc11_state_id=='{bihar_state_id}'")
    .assign(town_village_name=lambda df: df["town_village_name"].str.lower())
    .reset_index(drop=True)
)
gdf_villages.info()
gdf_villages.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 45107 entries, 0 to 45106
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   pc11_state_id         45107 non-null  object
#  1   pc11_district_id      45107 non-null  object
#  2   pc11_subdistrict_id   45107 non-null  object
#  3   pc11_town_village_id  45107 non-null  object
#  4   town_village_name     45072 non-null  object
#  5   geometry              45107 non-null  geometry
# dtypes: geometry(1), object(5)
# memory usage: 2.1+ MB
#   pc11_state_id pc11_district_id pc11_subdistrict_id pc11_town_village_id
# 0            10              203               01013               215989  \
# 1            10              203               01013               215990
# 2            10              203               01013               215991
# 3            10              203               01013               215992
# 4            10              203               01013               215993
#
#   town_village_name                                           geometry
# 0          kalapani  POLYGON ((83.95195 27.44241, 83.95057 27.44029...
# 1       bhaisalotan  POLYGON ((83.94735 27.44297, 83.94446 27.44172...
# 2            tharhi  POLYGON ((83.86745 27.43616, 83.87093 27.43540...
# 3             pipra  POLYGON ((83.90969 27.40805, 83.90759 27.40606...
# 4          kotaraha  POLYGON ((83.91060 27.39674, 83.90982 27.39623...

# %% [markdown]
# ## Divisions (subdistricts?): Land records
#
# * https://github.com/soodoku/land/blob/main/scripts/00_summary_basic_bihar_land_record.ipynb

# %%
fp_divisions = "divisions.csv"
if False:
    # Get divisions
    df_divisions = (
        get_fulldata(**{'usecols': ["division"]})
        .drop_duplicates(ignore_index=True)
        .assign(eng=np.nan)
    )
    # Transliterate
    for ix, row in tqdm(df_divisions.iterrows()):
        df_divisions.at[ix, "eng"] = transliterate.hindi2english(row["division"])
        
    df_divisions.to_csv(fp_divisions, index=False)
    
df_divisions = pd.read_csv(fp_divisions)
df_divisions.head(3)
# Out:
#        division              eng
# 0        वैशाली         vaishali
# 1  पटेढ़ी बेलसर  patedhi beluser
# 2        लालगंज          lalganj

# %%
df_divisions[df_divisions.duplicated("eng", keep=False)]
# Out:
#           division         eng
# 83       संग्रमपुर  sangrampur
# 106        बाराहाट     barahat
# 177           बरहट     barahat
# 268       सा0 कमाल         NaN
# 276  चे0 बरियारपुर         NaN
# 366        बगहा -1         NaN
# 450     संग्रामपुर  sangrampur

# %%
# Try merge with SHRUG
df_divisions = (
    df_divisions
    .dropna(subset=["eng"])
    .drop_duplicates("eng")
    .merge(gdf_subdistricts, how="outer", left_on="eng", right_on="subdistrict_name", validate="1:m", indicator=True)
)
df_divisions
# Out:
#          division              eng pc11_state_id pc11_district_id
# 0          वैशाली         vaishali            10              220  \
# 1    पटेढ़ी बेलसर  patedhi beluser           NaN              NaN
# 2          लालगंज          lalganj            10              220
# 3        भगवानपुर       bhagwanpur            10              220
# 4        भगवानपुर       bhagwanpur            10              222
# ..            ...              ...           ...              ...
# 811           NaN              NaN            10              239
# 812           NaN              NaN            10              239
# 813           NaN              NaN            10              239
# 814           NaN              NaN            10              240
# 815           NaN              NaN            10              240
#
#     pc11_subdistrict_id           subdistrict_name
# 0                 01268                   vaishali  \
# 1                   NaN                        NaN
# 2                 01270                    lalganj
# 3                 01271                 bhagwanpur
# 4                 01308                 bhagwanpur
# ..                  ...                        ...
# 811               01537                       kako
# 812               01538                  modanganj
# 813               01540                 makhdumpur
# 814               01542                      arwal
# 815               01545  sonbhadra banshi suryapur
#
#                                               geometry      _merge
# 0    POLYGON ((85.17616 26.00890, 85.17655 26.00858...        both
# 1                                                 None   left_only
# 2    POLYGON ((85.27043 25.91443, 85.26983 25.91342...        both
# 3    POLYGON ((85.28554 25.93287, 85.28608 25.93210...        both
# 4    POLYGON ((85.97766 25.62317, 85.97795 25.62281...        both
# ..                                                 ...         ...
# 811  POLYGON ((85.09374 25.28850, 85.09469 25.28781...  right_only
# 812  POLYGON ((85.14576 25.31181, 85.14654 25.31180...  right_only
# 813  POLYGON ((85.07797 25.15016, 85.07815 25.14854...  right_only
# 814  POLYGON ((84.70671 25.31483, 84.70909 25.31016...  right_only
# 815  POLYGON ((84.74671 25.15270, 84.74924 25.15170...  right_only
#
# [816 rows x 8 columns]

# %%
df_divisions.query("_merge=='both'")
# Out:
#      division         eng pc11_state_id pc11_district_id pc11_subdistrict_id
# 0      वैशाली    vaishali            10              220               01268  \
# 2      लालगंज     lalganj            10              220               01270
# 3    भगवानपुर  bhagwanpur            10              220               01271
# 4    भगवानपुर  bhagwanpur            10              222               01308
# 5    भगवानपुर  bhagwanpur            10              233               01455
# ..        ...         ...           ...              ...                 ...
# 503      औराई       aurai            10              216               01207
# 504      कटरा       katra            10              216               01208
# 505     काँटी       kanti            10              216               01204
# 508  साहेबगंज   sahebganj            10              216               01199
# 510     सरैया     saraiya            10              216               01202
#
#     subdistrict_name                                           geometry _merge
# 0           vaishali  POLYGON ((85.17616 26.00890, 85.17655 26.00858...   both
# 2            lalganj  POLYGON ((85.27043 25.91443, 85.26983 25.91342...   both
# 3         bhagwanpur  POLYGON ((85.28554 25.93287, 85.28608 25.93210...   both
# 4         bhagwanpur  POLYGON ((85.97766 25.62317, 85.97795 25.62281...   both
# 5         bhagwanpur  POLYGON ((83.62819 25.01638, 83.62923 25.01636...   both
# ..               ...                                                ...    ...
# 503            aurai  POLYGON ((85.58092 26.39322, 85.58173 26.39088...   both
# 504            katra  POLYGON ((85.65221 26.32562, 85.65257 26.32386...   both
# 505            kanti  MULTIPOLYGON (((85.38662 26.14974, 85.38624 26...   both
# 508        sahebganj  POLYGON ((85.01314 26.32546, 85.01443 26.32402...   both
# 510          saraiya  POLYGON ((85.13151 26.16455, 85.13193 26.16455...   both
#
# [229 rows x 8 columns]

# %%
df_divisions.query("_merge=='left_only'")
# Out:
#          division              eng pc11_state_id pc11_district_id
# 1    पटेढ़ी बेलसर  patedhi beluser           NaN              NaN  \
# 7         विदुपुर          vidupur           NaN              NaN
# 8         राधोपुर         radhopur           NaN              NaN
# 12      चेहरा कलॉ     chehra kalau           NaN              NaN
# 13       राजापाकर        rajapakar           NaN              NaN
# ..            ...              ...           ...              ...
# 500         बंदरा          bandara           NaN              NaN
# 501        बोचहाँ         bochahan           NaN              NaN
# 506          पारु             paru           NaN              NaN
# 507       मोतीपुर          motipur           NaN              NaN
# 509        कुढ्नी           kudhni           NaN              NaN
#
#     pc11_subdistrict_id subdistrict_name geometry     _merge
# 1                   NaN              NaN     None  left_only
# 7                   NaN              NaN     None  left_only
# 8                   NaN              NaN     None  left_only
# 12                  NaN              NaN     None  left_only
# 13                  NaN              NaN     None  left_only
# ..                  ...              ...      ...        ...
# 500                 NaN              NaN     None  left_only
# 501                 NaN              NaN     None  left_only
# 506                 NaN              NaN     None  left_only
# 507                 NaN              NaN     None  left_only
# 509                 NaN              NaN     None  left_only
#
# [282 rows x 8 columns]

# %%
df_divisions.query("_merge=='right_only'")
# Out:
#     division  eng pc11_state_id pc11_district_id pc11_subdistrict_id
# 511      NaN  NaN            10              203               01013  \
# 512      NaN  NaN            10              203               01014
# 513      NaN  NaN            10              203               01016
# 514      NaN  NaN            10              203               01017
# 515      NaN  NaN            10              203               01018
# ..       ...  ...           ...              ...                 ...
# 811      NaN  NaN            10              239               01537
# 812      NaN  NaN            10              239               01538
# 813      NaN  NaN            10              239               01540
# 814      NaN  NaN            10              240               01542
# 815      NaN  NaN            10              240               01545
#
#               subdistrict_name
# 511                     sidhaw  \
# 512                   ramnagar
# 513                  mainatanr
# 514               narkatiaganj
# 515                    lauriya
# ..                         ...
# 811                       kako
# 812                  modanganj
# 813                 makhdumpur
# 814                      arwal
# 815  sonbhadra banshi suryapur
#
#                                               geometry      _merge
# 511  POLYGON ((83.94735 27.44297, 83.94897 27.44205...  right_only
# 512  POLYGON ((84.12469 27.51105, 84.12628 27.51085...  right_only
# 513  POLYGON ((84.65097 27.29101, 84.65572 27.28294...  right_only
# 514  POLYGON ((84.58513 27.19071, 84.58565 27.19002...  right_only
# 515  POLYGON ((84.37649 27.06930, 84.37713 27.06922...  right_only
# ..                                                 ...         ...
# 811  POLYGON ((85.09374 25.28850, 85.09469 25.28781...  right_only
# 812  POLYGON ((85.14576 25.31181, 85.14654 25.31180...  right_only
# 813  POLYGON ((85.07797 25.15016, 85.07815 25.14854...  right_only
# 814  POLYGON ((84.70671 25.31483, 84.70909 25.31016...  right_only
# 815  POLYGON ((84.74671 25.15270, 84.74924 25.15170...  right_only
#
# [305 rows x 8 columns]

# %% [markdown]
# ## Districts: Land records

# %%
fp_districts = "districts.csv"
if False:
    # Get district
    df_districts = (
        get_fulldata(**{'usecols': ["district"]})
        .drop_duplicates(ignore_index=True)
        .assign(eng=np.nan)
    )
    # Transliterate
    for ix, row in tqdm(df_districts.iterrows()):
        df_districts.at[ix, "eng"] = transliterate.hindi2english(row["district"])
        
    df_districts.to_csv(fp_districts, index=False)
    
df_districts = pd.read_csv(fp_districts)
df_districts.head(3)
# Out:
# 0it [00:00, ?it/s]
#   district       eng
# 0   वैशाली  vaishali
# 1      गया      gaya
# 2   रोहतास    rohtas

# %%
# Try merge with SHRUG
df_districts = (
    df_districts
#     .dropna(subset=["eng"])
#     .drop_duplicates("eng")
    .merge(gdf_districts, how="outer", left_on="eng", right_on="district_name", validate="1:1", indicator=True)
)
df_districts
# Out:
#           district                 eng pc11_state_id pc11_district_id
# 0           वैशाली            vaishali            10              220  \
# 1              गया                gaya            10              236
# 2           रोहतास              rohtas            10              234
# 3        समस्तीपुर          samastipur            10              221
# 4           मुंगेर              munger            10              226
# 5            बक्सर             bucksre           NaN              NaN
# 6           अररिया              araria            10              209
# 7            बांका               banka            10              225
# 8            सुपौल              supaul            10              208
# 9            शिवहर            shivahar           NaN              NaN
# 10         भागलपुर           bhagalpur            10              224
# 11          नालंदा             nalanda            10              229
# 12         शेखपुरा           shekhpura           NaN              NaN
# 13            जमुई               jamui            10              238
# 14           सहरसा             saharsa            10              214
# 15        गोपालगंज           gopalganj            10              217
# 16           नवादा              navada           NaN              NaN
# 17          दरभंगा           darbhanga            10              215
# 18            पटना               patna            10              230
# 19        बेगुसराए           begusaray           NaN              NaN
# 20            अरवल              araval           NaN              NaN
# 21         किशनगंज          kishenganj           NaN              NaN
# 22            सारण               saran            10              219
# 23          कटिहार             katihar            10              212
# 24         सीतामढ़ी           sitamadhi           NaN              NaN
# 25          खगड़िया            khagriya           NaN              NaN
# 26       पूर्णियॉं      purniyaaayaaon           NaN              NaN
# 27   पश्चिम चंपारण  pashchim champaran            10              203
# 28          मधुबनी           madhubani            10              207
# 29           सिवान               sivan           NaN              NaN
# 30          भोजपुर             bhojpur            10              231
# 31         लखीसराय          lakhisarai            10              227
# 32        जहानाबाद           jahanabad           NaN              NaN
# 33           कैमूर               camor           NaN              NaN
# 34  पूर्वी चम्पारण     purvi champaran           NaN              NaN
# 35        औरंगाबाद          aurangabad            10              235
# 36         मधेपुरा           madhepura            10              213
# 37      मुज़फ्फरपुर           muzfarpur           NaN              NaN
# 38             NaN                 NaN            10              204
# 39             NaN                 NaN            10              205
# 40             NaN                 NaN            10              206
# 41             NaN                 NaN            10              210
# 42             NaN                 NaN            10              211
# 43             NaN                 NaN            10              216
# 44             NaN                 NaN            10              218
# 45             NaN                 NaN            10              222
# 46             NaN                 NaN            10              223
# 47             NaN                 NaN            10              228
# 48             NaN                 NaN            10              232
# 49             NaN                 NaN            10              233
# 50             NaN                 NaN            10              237
# 51             NaN                 NaN            10              239
# 52             NaN                 NaN            10              240
#
#          district_name                                           geometry
# 0             vaishali  POLYGON ((85.25131 26.00914, 85.25170 26.00909...  \
# 1                 gaya  MULTIPOLYGON (((84.51472 24.25770, 84.51427 24...
# 2               rohtas  POLYGON ((84.05529 25.37326, 84.05681 25.37270...
# 3           samastipur  POLYGON ((85.71753 26.08220, 85.71798 26.08212...
# 4               munger  POLYGON ((86.56461 25.49128, 86.56803 25.49122...
# 5                  NaN                                               None
# 6               araria  POLYGON ((87.06975 26.56275, 87.06950 26.55288...
# 7                banka  POLYGON ((86.73864 25.12136, 86.73858 25.12072...
# 8               supaul  POLYGON ((87.05293 26.55341, 87.05334 26.55334...
# 9                  NaN                                               None
# 10           bhagalpur  POLYGON ((87.09845 25.49145, 87.09792 25.48972...
# 11             nalanda  POLYGON ((85.41586 25.44830, 85.41675 25.44783...
# 12                 NaN                                               None
# 13               jamui  POLYGON ((86.40714 25.09627, 86.40500 25.09240...
# 14             saharsa  POLYGON ((86.43670 26.06372, 86.43714 26.06352...
# 15           gopalganj  POLYGON ((84.11410 26.63336, 84.11439 26.63334...
# 16                 NaN                                               None
# 17           darbhanga  POLYGON ((85.71936 26.44483, 85.72029 26.44397...
# 18               patna  POLYGON ((84.99418 25.73146, 84.99470 25.73145...
# 19                 NaN                                               None
# 20                 NaN                                               None
# 21                 NaN                                               None
# 22               saran  POLYGON ((84.87313 26.21165, 84.87369 26.21163...
# 23             katihar  POLYGON ((87.82502 25.88259, 87.82553 25.88247...
# 24                 NaN                                               None
# 25                 NaN                                               None
# 26                 NaN                                               None
# 27  pashchim champaran  POLYGON ((84.12469 27.51105, 84.12628 27.51085...
# 28           madhubani  POLYGON ((86.06059 26.65650, 86.06645 26.65505...
# 29                 NaN                                               None
# 30             bhojpur  POLYGON ((84.69442 25.75236, 84.69464 25.75111...
# 31          lakhisarai  POLYGON ((86.11032 25.31469, 86.11215 25.31451...
# 32                 NaN                                               None
# 33                 NaN                                               None
# 34                 NaN                                               None
# 35          aurangabad  POLYGON ((84.46874 25.09176, 84.46984 25.09157...
# 36           madhepura  POLYGON ((86.74821 26.11318, 86.74886 26.11224...
# 37                 NaN                                               None
# 38     purba champaran  POLYGON ((84.83041 27.01919, 84.83128 27.01916...
# 39             sheohar  POLYGON ((85.32738 26.65375, 85.32803 26.65304...
# 40           sitamarhi  POLYGON ((85.66200 26.84586, 85.66625 26.84437...
# 41          kishanganj  MULTIPOLYGON (((87.84553 25.98449, 87.84566 25...
# 42              purnia  POLYGON ((87.71802 26.11298, 87.71835 26.11297...
# 43         muzaffarpur  POLYGON ((85.58092 26.39322, 85.58173 26.39088...
# 44               siwan  POLYGON ((84.40285 26.36415, 84.40395 26.36356...
# 45           begusarai  POLYGON ((86.12759 25.76362, 86.12795 25.76341...
# 46            khagaria  POLYGON ((86.40191 25.73625, 86.40280 25.73601...
# 47          sheikhpura  POLYGON ((85.73666 25.27670, 85.73670 25.27618...
# 48               buxar  MULTIPOLYGON (((84.14912 25.72990, 84.14822 25...
# 49     kaimur (bhabua)  MULTIPOLYGON (((83.33928 25.18009, 83.33889 25...
# 50              nawada  POLYGON ((85.68174 25.10746, 85.68207 25.10744...
# 51           jehanabad  POLYGON ((85.00455 25.31710, 85.00495 25.31684...
# 52               arwal  POLYGON ((84.70671 25.31483, 84.70909 25.31016...
#
#         _merge
# 0         both
# 1         both
# 2         both
# 3         both
# 4         both
# 5    left_only
# 6         both
# 7         both
# 8         both
# 9    left_only
# 10        both
# 11        both
# 12   left_only
# 13        both
# 14        both
# 15        both
# 16   left_only
# 17        both
# 18        both
# 19   left_only
# 20   left_only
# 21   left_only
# 22        both
# 23        both
# 24   left_only
# 25   left_only
# 26   left_only
# 27        both
# 28        both
# 29   left_only
# 30        both
# 31        both
# 32   left_only
# 33   left_only
# 34   left_only
# 35        both
# 36        both
# 37   left_only
# 38  right_only
# 39  right_only
# 40  right_only
# 41  right_only
# 42  right_only
# 43  right_only
# 44  right_only
# 45  right_only
# 46  right_only
# 47  right_only
# 48  right_only
# 49  right_only
# 50  right_only
# 51  right_only
# 52  right_only

# %%
df_districts.sort_values("_merge")
# Out:
#           district                 eng pc11_state_id pc11_district_id
# 26       पूर्णियॉं      purniyaaayaaon           NaN              NaN  \
# 25          खगड़िया            khagriya           NaN              NaN
# 24         सीतामढ़ी           sitamadhi           NaN              NaN
# 33           कैमूर               camor           NaN              NaN
# 34  पूर्वी चम्पारण     purvi champaran           NaN              NaN
# 21         किशनगंज          kishenganj           NaN              NaN
# 20            अरवल              araval           NaN              NaN
# 19        बेगुसराए           begusaray           NaN              NaN
# 37      मुज़फ्फरपुर           muzfarpur           NaN              NaN
# 16           नवादा              navada           NaN              NaN
# 32        जहानाबाद           jahanabad           NaN              NaN
# 12         शेखपुरा           shekhpura           NaN              NaN
# 29           सिवान               sivan           NaN              NaN
# 9            शिवहर            shivahar           NaN              NaN
# 5            बक्सर             bucksre           NaN              NaN
# 43             NaN                 NaN            10              216
# 40             NaN                 NaN            10              206
# 39             NaN                 NaN            10              205
# 38             NaN                 NaN            10              204
# 44             NaN                 NaN            10              218
# 45             NaN                 NaN            10              222
# 46             NaN                 NaN            10              223
# 47             NaN                 NaN            10              228
# 48             NaN                 NaN            10              232
# 49             NaN                 NaN            10              233
# 50             NaN                 NaN            10              237
# 42             NaN                 NaN            10              211
# 41             NaN                 NaN            10              210
# 52             NaN                 NaN            10              240
# 51             NaN                 NaN            10              239
# 27   पश्चिम चंपारण  pashchim champaran            10              203
# 1              गया                gaya            10              236
# 2           रोहतास              rohtas            10              234
# 3        समस्तीपुर          samastipur            10              221
# 4           मुंगेर              munger            10              226
# 6           अररिया              araria            10              209
# 7            बांका               banka            10              225
# 8            सुपौल              supaul            10              208
# 10         भागलपुर           bhagalpur            10              224
# 11          नालंदा             nalanda            10              229
# 13            जमुई               jamui            10              238
# 14           सहरसा             saharsa            10              214
# 15        गोपालगंज           gopalganj            10              217
# 17          दरभंगा           darbhanga            10              215
# 18            पटना               patna            10              230
# 36         मधेपुरा           madhepura            10              213
# 35        औरंगाबाद          aurangabad            10              235
# 22            सारण               saran            10              219
# 23          कटिहार             katihar            10              212
# 31         लखीसराय          lakhisarai            10              227
# 30          भोजपुर             bhojpur            10              231
# 28          मधुबनी           madhubani            10              207
# 0           वैशाली            vaishali            10              220
#
#          district_name                                           geometry
# 26                 NaN                                               None  \
# 25                 NaN                                               None
# 24                 NaN                                               None
# 33                 NaN                                               None
# 34                 NaN                                               None
# 21                 NaN                                               None
# 20                 NaN                                               None
# 19                 NaN                                               None
# 37                 NaN                                               None
# 16                 NaN                                               None
# 32                 NaN                                               None
# 12                 NaN                                               None
# 29                 NaN                                               None
# 9                  NaN                                               None
# 5                  NaN                                               None
# 43         muzaffarpur  POLYGON ((85.58092 26.39322, 85.58173 26.39088...
# 40           sitamarhi  POLYGON ((85.66200 26.84586, 85.66625 26.84437...
# 39             sheohar  POLYGON ((85.32738 26.65375, 85.32803 26.65304...
# 38     purba champaran  POLYGON ((84.83041 27.01919, 84.83128 27.01916...
# 44               siwan  POLYGON ((84.40285 26.36415, 84.40395 26.36356...
# 45           begusarai  POLYGON ((86.12759 25.76362, 86.12795 25.76341...
# 46            khagaria  POLYGON ((86.40191 25.73625, 86.40280 25.73601...
# 47          sheikhpura  POLYGON ((85.73666 25.27670, 85.73670 25.27618...
# 48               buxar  MULTIPOLYGON (((84.14912 25.72990, 84.14822 25...
# 49     kaimur (bhabua)  MULTIPOLYGON (((83.33928 25.18009, 83.33889 25...
# 50              nawada  POLYGON ((85.68174 25.10746, 85.68207 25.10744...
# 42              purnia  POLYGON ((87.71802 26.11298, 87.71835 26.11297...
# 41          kishanganj  MULTIPOLYGON (((87.84553 25.98449, 87.84566 25...
# 52               arwal  POLYGON ((84.70671 25.31483, 84.70909 25.31016...
# 51           jehanabad  POLYGON ((85.00455 25.31710, 85.00495 25.31684...
# 27  pashchim champaran  POLYGON ((84.12469 27.51105, 84.12628 27.51085...
# 1                 gaya  MULTIPOLYGON (((84.51472 24.25770, 84.51427 24...
# 2               rohtas  POLYGON ((84.05529 25.37326, 84.05681 25.37270...
# 3           samastipur  POLYGON ((85.71753 26.08220, 85.71798 26.08212...
# 4               munger  POLYGON ((86.56461 25.49128, 86.56803 25.49122...
# 6               araria  POLYGON ((87.06975 26.56275, 87.06950 26.55288...
# 7                banka  POLYGON ((86.73864 25.12136, 86.73858 25.12072...
# 8               supaul  POLYGON ((87.05293 26.55341, 87.05334 26.55334...
# 10           bhagalpur  POLYGON ((87.09845 25.49145, 87.09792 25.48972...
# 11             nalanda  POLYGON ((85.41586 25.44830, 85.41675 25.44783...
# 13               jamui  POLYGON ((86.40714 25.09627, 86.40500 25.09240...
# 14             saharsa  POLYGON ((86.43670 26.06372, 86.43714 26.06352...
# 15           gopalganj  POLYGON ((84.11410 26.63336, 84.11439 26.63334...
# 17           darbhanga  POLYGON ((85.71936 26.44483, 85.72029 26.44397...
# 18               patna  POLYGON ((84.99418 25.73146, 84.99470 25.73145...
# 36           madhepura  POLYGON ((86.74821 26.11318, 86.74886 26.11224...
# 35          aurangabad  POLYGON ((84.46874 25.09176, 84.46984 25.09157...
# 22               saran  POLYGON ((84.87313 26.21165, 84.87369 26.21163...
# 23             katihar  POLYGON ((87.82502 25.88259, 87.82553 25.88247...
# 31          lakhisarai  POLYGON ((86.11032 25.31469, 86.11215 25.31451...
# 30             bhojpur  POLYGON ((84.69442 25.75236, 84.69464 25.75111...
# 28           madhubani  POLYGON ((86.06059 26.65650, 86.06645 26.65505...
# 0             vaishali  POLYGON ((85.25131 26.00914, 85.25170 26.00909...
#
#         _merge
# 26   left_only
# 25   left_only
# 24   left_only
# 33   left_only
# 34   left_only
# 21   left_only
# 20   left_only
# 19   left_only
# 37   left_only
# 16   left_only
# 32   left_only
# 12   left_only
# 29   left_only
# 9    left_only
# 5    left_only
# 43  right_only
# 40  right_only
# 39  right_only
# 38  right_only
# 44  right_only
# 45  right_only
# 46  right_only
# 47  right_only
# 48  right_only
# 49  right_only
# 50  right_only
# 42  right_only
# 41  right_only
# 52  right_only
# 51  right_only
# 27        both
# 1         both
# 2         both
# 3         both
# 4         both
# 6         both
# 7         both
# 8         both
# 10        both
# 11        both
# 13        both
# 14        both
# 15        both
# 17        both
# 18        both
# 36        both
# 35        both
# 22        both
# 23        both
# 31        both
# 30        both
# 28        both
# 0         both

# %% [markdown]
# ## Residence (villages?): Land Records

# %%
fp_residences = "residences.csv"
if True:
    # Get district
    df_residences = (
        get_fulldata(**{'usecols': ["district"]})
        .drop_duplicates(ignore_index=True)
        .assign(eng=np.nan)
    )
    # Transliterate
    for ix, row in tqdm(df_residences.iterrows()):
        df_residences.at[ix, "eng"] = transliterate.hindi2english(row["district"])
        
    df_residences.to_csv(fp_residences, index=False)
    
df_residences = pd.read_csv(fp_residences)
df_residences.head(3)
# Out:
# 0it [00:00, ?it/s]
#   district       eng
# 0   वैशाली  vaishali
# 1      गया      gaya
# 2   रोहतास    rohtas
