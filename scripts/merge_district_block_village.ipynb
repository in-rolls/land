# %%
import re
import pandas as pd
pd.set_option('display.max_columns', 50)
import janitor
from utilities.utils import get_fulldata

usecols = ["district", "division", "mouza"]
geo_slugs = ['zilla_district_lr', 'anchal_block_lr', 'mauja_village_lr']


# Get Bihar land record data
df = (get_fulldata(**{'usecols':usecols})
      .rename_column("district", "zilla_district_lr")
      .rename_column("division", "anchal_block_lr")
      .rename_column("mouza", "mauja_village_lr")
      # Make sure no whitespaces screw up the merge
      .assign(
          **{col: lambda df, k=col: df[k].str.strip() for col in geo_slugs}
      )  
      .drop_duplicates(geo_slugs)
      .reset_index(drop=True)
     )
df.shape
df
# Out:
#       zilla_district_lr anchal_block_lr        mauja_village_lr
# 0                वैशाली          वैशाली              चकपिताम्बर
# 1                वैशाली          वैशाली                   सिमरा
# 2                वैशाली          वैशाली                  फुलाढ़
# 3                वैशाली          वैशाली                मंसूरपुर
# 4                वैशाली          वैशाली  चकना मारूफ उर्फ़ चकनथुआ
# ...                 ...             ...                     ...
# 35623        मुज़फ्फरपुर           सरैया               बैघा टोला
# 35624        मुज़फ्फरपुर           सरैया       आनन्दपुर गंगोलिया
# 35625        मुज़फ्फरपुर           सरैया       विशुनपुर दुवियाही
# 35626        मुज़फ्फरपुर           सरैया               शादीक पुर
# 35627        मुज़फ्फरपुर           सरैया               बैधा टोला
#
# [35628 rows x 3 columns]

# %%
# Get crosswalk data (from Aaditya)
df_xwalk = (
    pd.read_stata("../data/br_lr_census_crosswalk.dta")
    .assign(anchal_block_lr=lambda df: df["anchal_block_lr"].apply(lambda x: re.sub(r"\[.*?\]", "", x)))
#     .assign(anchal_block_lr=lambda df: df["anchal_block_lr"].str.strip())
#       Make sure no whitespaces screw up the merge
      .assign(
          **{col: lambda df, k=col: df[k].str.strip() for col in geo_slugs}
      )    
    # village is not the lowest geographical unit
    .drop_duplicates(geo_slugs)
    .reset_index(drop=True)
)
df_xwalk.shape
df_xwalk
# Out:
#       zilla_district_lr  zilla_district_lr_code anumandal_subdiv_lr
# 0              जहानाबाद                      33            जहानाबाद  \
# 1              जहानाबाद                      33            जहानाबाद
# 2              जहानाबाद                      33            जहानाबाद
# 3              जहानाबाद                      33            जहानाबाद
# 4              जहानाबाद                      33            जहानाबाद
# ...                 ...                     ...                 ...
# 40952             सहरसा                      12   सिमरी बख्तियारपुर
# 40953             सहरसा                      12   सिमरी बख्तियारपुर
# 40954             सहरसा                      12   सिमरी बख्तियारपुर
# 40955             सहरसा                      12   सिमरी बख्तियारपुर
# 40956             सहरसा                      12   सिमरी बख्तियारपुर
#
#        anumandal_subdiv_lr_code anchal_block_lr  anchal_circle_lr_code
# 0                             1        जहानाबाद                      1  \
# 1                             1        जहानाबाद                      1
# 2                             1        जहानाबाद                      1
# 3                             1        जहानाबाद                      1
# 4                             1        जहानाबाद                      1
# ...                         ...             ...                    ...
# 40952                         2     बनमा ईटहारी                     10
# 40953                         2     बनमा ईटहारी                     10
# 40954                         2     बनमा ईटहारी                     10
# 40955                         2     बनमा ईटहारी                     10
# 40956                         2     बनमा ईटहारी                     10
#
#       mauja_village_lr revenue_station_no_lr  total_kasara_lr
# 0                अंजनी                   407              235  \
# 1              अंजनीचक                   405               27
# 2               अदलुचक                   381               92
# 3                 अमैन                   366              765
# 4                 अरसठ                    28               14
# ...                ...                   ...              ...
# 40952     शमसुद्दीनपुर                    94             1681
# 40953            सुगमा                   132              790
# 40954          सर्वेला                    89                0
# 40955          सहुरिया                   130                0
# 40956           हथमंडल                   116                0
#
#        total_accounts_lr statecode_census statename_census
# 0                    182               10            BIHAR  \
# 1                     19               10            BIHAR
# 2                     82               10            BIHAR
# 3                    614               10            BIHAR
# 4                      7               10            BIHAR
# ...                  ...              ...              ...
# 40952                266               10            BIHAR
# 40953                145               10            BIHAR
# 40954                  0               10            BIHAR
# 40955                  0               10            BIHAR
# 40956                  0               10            BIHAR
#
#       districtcode_census districtname_census subdistrictcode_census
# 0                     239          Jehanabad                   01536  \
# 1                     239          Jehanabad                   01536
# 2                     239          Jehanabad                   01536
# 3                     239          Jehanabad                   01536
# 4                     239          Jehanabad                   01536
# ...                   ...                 ...                    ...
# 40952                 214             Saharsa                  01180
# 40953                 214             Saharsa                  01180
# 40954                 214             Saharsa                  01180
# 40955                 214             Saharsa                  01180
# 40956                 214             Saharsa                  01180
#
#       subdistrictname_census cdblockcode_census cdblockname_census
# 0                  Jehanabad               0524          Jehanabad  \
# 1                  Jehanabad               0524          Jehanabad
# 2                  Jehanabad               0524          Jehanabad
# 3                  Jehanabad               0524          Jehanabad
# 4                  Jehanabad               0524          Jehanabad
# ...                      ...                ...                ...
# 40952           Banma Itahri               0168       Banma Itahri
# 40953           Banma Itahri               0168       Banma Itahri
# 40954           Banma Itahri               0168       Banma Itahri
# 40955           Banma Itahri               0168       Banma Itahri
# 40956           Banma Itahri               0168       Banma Itahri
#
#       grampanchayatcode_census grampanchayatname_census villagecode_census
# 0                         0003              Mandevigaha             260211  \
# 1                         0003              Mandevigaha             260209
# 2                         0010                   Pandui             260196
# 3                         0011                    Amain             260182
# 4                         0001   Surungapur Bhavanichak             260142
# ...                        ...                      ...                ...
# 40952                     0005                  MAHARAS             226694
# 40953                     0002                  SAHURIA             226705
# 40954                     0006                  SARBELA             226690
# 40955               0001, 0002          ITAHRI, SAHURIA             226704
# 40956                     0001                   ITAHRI             226703
#
#       villagename_census
# 0                 Anjani
# 1             Anjanichak
# 2               Adluchak
# 3                  Amain
# 4                 Arsath
# ...                  ...
# 40952      Shamsuddinpur
# 40953              Sugma
# 40954            Sarbela
# 40955            Sahuria
# 40956        Hath Mandal
#
# [40957 rows x 22 columns]

# %%
# Attempt merge between Bihar data and the crosswalk
df_merged = (
    df.merge(df_xwalk, how="left", on=geo_slugs, validate="1:1", indicator=True)
)
df_merge
# Out:
#       zilla_district_lr anchal_block_lr        mauja_village_lr
# 0                वैशाली          वैशाली              चकपिताम्बर  \
# 1                वैशाली          वैशाली                   सिमरा
# 2                वैशाली          वैशाली                  फुलाढ़
# 3                वैशाली          वैशाली                मंसूरपुर
# 4                वैशाली          वैशाली  चकना मारूफ उर्फ़ चकनथुआ
# ...                 ...             ...                     ...
# 35623        मुज़फ्फरपुर           सरैया               बैघा टोला
# 35624        मुज़फ्फरपुर           सरैया       आनन्दपुर गंगोलिया
# 35625        मुज़फ्फरपुर           सरैया       विशुनपुर दुवियाही
# 35626        मुज़फ्फरपुर           सरैया               शादीक पुर
# 35627        मुज़फ्फरपुर           सरैया               बैधा टोला
#
#        zilla_district_lr_code anumandal_subdiv_lr  anumandal_subdiv_lr_code
# 0                        18.0             हाजीपुर                       1.0  \
# 1                        18.0             हाजीपुर                       1.0
# 2                        18.0             हाजीपुर                       1.0
# 3                        18.0             हाजीपुर                       1.0
# 4                        18.0             हाजीपुर                       1.0
# ...                       ...                 ...                       ...
# 35623                     NaN                 NaN                       NaN
# 35624                     NaN                 NaN                       NaN
# 35625                     NaN                 NaN                       NaN
# 35626                     NaN                 NaN                       NaN
# 35627                     NaN                 NaN                       NaN
#
#        anchal_circle_lr_code revenue_station_no_lr  total_kasara_lr
# 0                        1.0                     1            472.0  \
# 1                        1.0                     2           1577.0
# 2                        1.0                     3           3331.0
# 3                        1.0                     4           1677.0
# 4                        1.0                     5            834.0
# ...                      ...                   ...              ...
# 35623                    NaN                   NaN              NaN
# 35624                    NaN                   NaN              NaN
# 35625                    NaN                   NaN              NaN
# 35626                    NaN                   NaN              NaN
# 35627                    NaN                   NaN              NaN
#
#        total_accounts_lr statecode_census statename_census
# 0                  107.0               10            BIHAR  \
# 1                  171.0               10            BIHAR
# 2                  404.0               10            BIHAR
# 3                  300.0               10            BIHAR
# 4                   94.0               10            BIHAR
# ...                  ...              ...              ...
# 35623                NaN              NaN              NaN
# 35624                NaN              NaN              NaN
# 35625                NaN              NaN              NaN
# 35626                NaN              NaN              NaN
# 35627                NaN              NaN              NaN
#
#       districtcode_census districtname_census subdistrictcode_census
# 0                     220            Vaishali                  01268  \
# 1                     220            Vaishali                  01268
# 2                     220            Vaishali                  01268
# 3                     220            Vaishali                  01268
# 4                     220            Vaishali                  01268
# ...                   ...                 ...                    ...
# 35623                 NaN                 NaN                    NaN
# 35624                 NaN                 NaN                    NaN
# 35625                 NaN                 NaN                    NaN
# 35626                 NaN                 NaN                    NaN
# 35627                 NaN                 NaN                    NaN
#
#       subdistrictname_census cdblockcode_census cdblockname_census
# 0                   Vaishali               0256           Vaishali  \
# 1                   Vaishali               0256           Vaishali
# 2                   Vaishali               0256           Vaishali
# 3                   Vaishali               0256           Vaishali
# 4                   Vaishali               0256           Vaishali
# ...                      ...                ...                ...
# 35623                    NaN                NaN                NaN
# 35624                    NaN                NaN                NaN
# 35625                    NaN                NaN                NaN
# 35626                    NaN                NaN                NaN
# 35627                    NaN                NaN                NaN
#
#       grampanchayatcode_census grampanchayatname_census villagecode_census
# 0                            1                   Fuladh             234576  \
# 1                            2              Chakalhadad             234577
# 2                            1                   Fuladh             234578
# 3                            1                   Fuladh             234579
# 4                            1                   Fuladh             234580
# ...                        ...                      ...                ...
# 35623                      NaN                      NaN                NaN
# 35624                      NaN                      NaN                NaN
# 35625                      NaN                      NaN                NaN
# 35626                      NaN                      NaN                NaN
# 35627                      NaN                      NaN                NaN
#
#              villagename_census     _merge
# 0                  ChakPitamber       both
# 1                         Simra       both
# 2                        Phular       both
# 3                     Mansurpur       both
# 4      Chakna Maruf Chak Nathua       both
# ...                         ...        ...
# 35623                       NaN  left_only
# 35624                       NaN  left_only
# 35625                       NaN  left_only
# 35626                       NaN  left_only
# 35627                       NaN  left_only
#
# [35628 rows x 23 columns]

# %%
df_merged["_merge"].describe()
# Out:
# count     35628
# unique        2
# top        both
# freq      27720
# Name: _merge, dtype: object

# %%
# No (district, block, village) tuple appear only in the crosswalk table (right table)
df_merged.query("_merge=='right_only'")
# Out:
# Empty DataFrame
# Columns: [zilla_district_lr, anchal_block_lr, mauja_village_lr, zilla_district_lr_code, anumandal_subdiv_lr, anumandal_subdiv_lr_code, anchal_circle_lr_code, revenue_station_no_lr, total_kasara_lr, total_accounts_lr, statecode_census, statename_census, districtcode_census, districtname_census, subdistrictcode_census, subdistrictname_census, cdblockcode_census, cdblockname_census, grampanchayatcode_census, grampanchayatname_census, villagecode_census, villagename_census, _merge]
# Index: []

# %%
# 7.9k (district, block, village) tuples appear only in the Bihar land record table (left table)
df_merged.query("_merge=='left_only'")
# Out:
#       zilla_district_lr anchal_block_lr       mauja_village_lr
# 200              वैशाली         हाजीपुर     सहलादपुर मितवार चक  \
# 440              वैशाली         हाजीपुर  चकरविया उर्फ रविया चक
# 1901                गया             नगर   नगरपालिका वार्ड न0-2
# 1911                गया             नगर    नगरपालीका वार्ड0 10
# 2362                गया            अतरी           वनबा गोसाईमठ
# ...                 ...             ...                    ...
# 35623        मुज़फ्फरपुर           सरैया              बैघा टोला
# 35624        मुज़फ्फरपुर           सरैया      आनन्दपुर गंगोलिया
# 35625        मुज़फ्फरपुर           सरैया      विशुनपुर दुवियाही
# 35626        मुज़फ्फरपुर           सरैया              शादीक पुर
# 35627        मुज़फ्फरपुर           सरैया              बैधा टोला
#
#        zilla_district_lr_code anumandal_subdiv_lr  anumandal_subdiv_lr_code
# 200                       NaN                 NaN                       NaN  \
# 440                       NaN                 NaN                       NaN
# 1901                      NaN                 NaN                       NaN
# 1911                      NaN                 NaN                       NaN
# 2362                      NaN                 NaN                       NaN
# ...                       ...                 ...                       ...
# 35623                     NaN                 NaN                       NaN
# 35624                     NaN                 NaN                       NaN
# 35625                     NaN                 NaN                       NaN
# 35626                     NaN                 NaN                       NaN
# 35627                     NaN                 NaN                       NaN
#
#        anchal_circle_lr_code revenue_station_no_lr  total_kasara_lr
# 200                      NaN                   NaN              NaN  \
# 440                      NaN                   NaN              NaN
# 1901                     NaN                   NaN              NaN
# 1911                     NaN                   NaN              NaN
# 2362                     NaN                   NaN              NaN
# ...                      ...                   ...              ...
# 35623                    NaN                   NaN              NaN
# 35624                    NaN                   NaN              NaN
# 35625                    NaN                   NaN              NaN
# 35626                    NaN                   NaN              NaN
# 35627                    NaN                   NaN              NaN
#
#        total_accounts_lr statecode_census statename_census
# 200                  NaN              NaN              NaN  \
# 440                  NaN              NaN              NaN
# 1901                 NaN              NaN              NaN
# 1911                 NaN              NaN              NaN
# 2362                 NaN              NaN              NaN
# ...                  ...              ...              ...
# 35623                NaN              NaN              NaN
# 35624                NaN              NaN              NaN
# 35625                NaN              NaN              NaN
# 35626                NaN              NaN              NaN
# 35627                NaN              NaN              NaN
#
#       districtcode_census districtname_census subdistrictcode_census
# 200                   NaN                 NaN                    NaN  \
# 440                   NaN                 NaN                    NaN
# 1901                  NaN                 NaN                    NaN
# 1911                  NaN                 NaN                    NaN
# 2362                  NaN                 NaN                    NaN
# ...                   ...                 ...                    ...
# 35623                 NaN                 NaN                    NaN
# 35624                 NaN                 NaN                    NaN
# 35625                 NaN                 NaN                    NaN
# 35626                 NaN                 NaN                    NaN
# 35627                 NaN                 NaN                    NaN
#
#       subdistrictname_census cdblockcode_census cdblockname_census
# 200                      NaN                NaN                NaN  \
# 440                      NaN                NaN                NaN
# 1901                     NaN                NaN                NaN
# 1911                     NaN                NaN                NaN
# 2362                     NaN                NaN                NaN
# ...                      ...                ...                ...
# 35623                    NaN                NaN                NaN
# 35624                    NaN                NaN                NaN
# 35625                    NaN                NaN                NaN
# 35626                    NaN                NaN                NaN
# 35627                    NaN                NaN                NaN
#
#       grampanchayatcode_census grampanchayatname_census villagecode_census
# 200                        NaN                      NaN                NaN  \
# 440                        NaN                      NaN                NaN
# 1901                       NaN                      NaN                NaN
# 1911                       NaN                      NaN                NaN
# 2362                       NaN                      NaN                NaN
# ...                        ...                      ...                ...
# 35623                      NaN                      NaN                NaN
# 35624                      NaN                      NaN                NaN
# 35625                      NaN                      NaN                NaN
# 35626                      NaN                      NaN                NaN
# 35627                      NaN                      NaN                NaN
#
#       villagename_census     _merge
# 200                  NaN  left_only
# 440                  NaN  left_only
# 1901                 NaN  left_only
# 1911                 NaN  left_only
# 2362                 NaN  left_only
# ...                  ...        ...
# 35623                NaN  left_only
# 35624                NaN  left_only
# 35625                NaN  left_only
# 35626                NaN  left_only
# 35627                NaN  left_only
#
# [7908 rows x 23 columns]

# %%
"नगरपालीका वार्ड0 10" in df_xwalk.mauja_village_lr.unique()
# Out:
# False

# %%
"नगरपालीका वार्ड" in df_xwalk.mauja_village_lr.unique()
# Out:
# False
