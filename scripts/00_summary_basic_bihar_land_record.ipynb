# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
import janitor
from utilities.utils import get_fulldata
from indicate import transliterate
import warnings
warnings.filterwarnings('ignore')

usecols = ['name_of_ryot', 'residence', 'district', 'division', 'caste', 'mouza', 'account_no', '6', '7', '8']
df = (get_fulldata(**{'usecols':usecols})
    .rename_columns(new_column_names={"6": "acres", "7": "decimals", "8": "hectare"})
      .assign(tt_area_acre=lambda df: df["acres"]+df["decimals"]/100)
     )
df.shape
# Out:
# (41871025, 11)

# %%
df.head(3)
# Out:
#    name_of_ryot   residence    caste district division       mouza  \
# 0  कपिलदेव पाठक  निजग्राम,,  ब्रहामण   वैशाली   वैशाली  चकपिताम्बर
# 1  कपिलदेव पाठक  निजग्राम,,  ब्रहामण   वैशाली   वैशाली  चकपिताम्बर
# 2  कपिलदेव पाठक  निजग्राम,,  ब्रहामण   वैशाली   वैशाली  चकपिताम्बर
#
#          account_no  acres  decimals  hectare  tt_area_acre
# 0  1801010001000002    0.0      66.0      0.0          0.66
# 1  1801010001000002    0.0       8.0      0.0          0.08
# 2  1801010001000002    0.0       6.0      0.0          0.06

# %%
# 12,127,297 account holders
df.account_no.nunique()
# Out:
# 12127297

# %%
len(df.query("acres<0"))
# Out:
# 0

# %%
len(df.query("decimals<0"))
# Out:
# 14

# %%
len(df.query("tt_area_acre<0"))
# Out:
# 14

# %%
len(df.query("tt_area_acre==0"))
# Out:
# 2973101

# %%
(df
      .query("acres>=0")
      .query("decimals>=0")
      .query("tt_area_acre>0")
 .shape
)
# Out:
# (38897910, 11)

# %%
(df
      .query("tt_area_acre>0")
 .shape
)
# Out:
# (38897910, 11)

# %%
(df
    .query("tt_area_acre>0")
 ["account_no"]
 .nunique()
)
# Out:
# 12031744

# %%
pd.set_option("display.float_format", "{:,.6f}".format)
(
    df
    .remove_columns(["account_no"])
    .query("tt_area_acre>0")
    .describe(percentiles=[.25,.5,.75,.95,.99,.995,.999,.9999])
)
# Out:
#                    acres          decimals           hectare      tt_area_acre
# count  38,897,910.000000 38,897,910.000000 38,897,910.000000 38,897,910.000000
# mean            0.630460         24.319360          6.018435         15.745809
# std         1,462.340106      2,799.010864        779.638953      2,419.822199
# min             0.000000          0.000000          0.000000          0.000000
# 25%             0.000000          6.000000          0.000000          0.065000
# 50%             0.000000         13.000000          0.000000          0.150000
# 75%             0.000000         29.000000          0.000000          0.355000
# 95%             1.000000         70.000000          0.037500          1.390000
# 99%             3.000000         92.000000          0.640000          6.800000
# 99.5%           5.000000         96.000000         57.000000        160.781500
# 99.9%          15.000000        205.000000      1,416.000000      3,499.427600
# 99.99%         96.000000      2,975.000000      6,272.000000     15,601.614300
# max     8,888,888.000000  7,899,260.000000  1,741,197.000000  8,888,888.210000

# %%
len(df.query("tt_area_acre>100_00"))
# Out:
# 9453

# %%
df.query("tt_area_acre>0")["tt_area_acre"].quantile(0.9947)
# Out:
# 101.3151

# %%
df.query("tt_area_acre>100_00")["account_no"].nunique()
# Out:
# 6097

# %%
100 * (6097/df.query("tt_area_acre>0")["account_no"].nunique())
# Out:
# 0.05067428296346731

# %%
len(df.query("tt_area_acre>100_00"))
# Out:
# 9453

# %%
100 * 9453 / (len(df.query("tt_area_acre>0")))
# Out:
# 0.024302076898218953

# %% [markdown]
# ### Residences

# %%
df.residence.nunique()
# Out:
# 830567

# %%
_df = df.head(100).drop_duplicates("residence", ignore_index=True)
for i in range(10):
    residence = _df.loc[i, "residence"]
    english_translated = transliterate.hindi2english(residence)
    print(f"{english_translated} ({residence})")
# Out:
# jamua (जमुआ,,,)
# dahgama (दहगामा,,,)
# pothiya (पोठीया,,,)
# ramangar (रामनगर,,,)
#  (,,,)
# pothi (पोठीय,,,)
# phulwari (फुलवारी,,,)
# phulwari (फुलवाड़ी,,,)
# belwari (बेलवारी,,,)
# bailvari (बैलवारी,,,)

# %% [markdown]
# ### Districts

# %%
for district in df.district.unique():
    english_translated = transliterate.hindi2english(district)
    print(f"{english_translated} ({district})")
# Out:
# araria (अररिया)
# araval (अरवल)
# aurangabad (औरंगाबाद)
# katihar (कटिहार)
# kishenganj (किशनगंज)
# camor (कैमूर)
# khagriya (खगड़िया)
# gaya (गया)
# gopalganj (गोपालगंज)
# jamui (जमुई)
# jahanabad (जहानाबाद)
# darbhanga (दरभंगा)
# navada (नवादा)
# nalanda (नालंदा)
# patna (पटना)
# pashchim champaran (पश्चिम चंपारण)
# purniyaaayaaon (पूर्णियॉं)
# purvi champaran (पूर्वी चम्पारण)
# bucksre (बक्सर)
# banka (बांका)
# begusaray (बेगुसराए)
# bhagalpur (भागलपुर)
# bhojpur (भोजपुर)
# madhubani (मधुबनी)
# madhepura (मधेपुरा)
# munger (मुंगेर)
# muzfarpur (मुज़फ्फरपुर)
# rohtas (रोहतास)
# lakhisarai (लखीसराय)
# vaishali (वैशाली)
# shivahar (शिवहर)
# shekhpura (शेखपुरा)
# samastipur (समस्तीपुर)
# saharsa (सहरसा)
# saran (सारण)
# sivan (सिवान)
# sitamadhi (सीतामढ़ी)
# supaul (सुपौल)

# %% [markdown]
# ### Divisions

# %%
df.division.nunique()
# Out:
# 505

# %%
_df = df.drop_duplicates("division", ignore_index=True)
for i in range(10):
    division = _df.loc[i, "division"]
    english_translated = transliterate.hindi2english(division)
    print(f"{english_translated} ({division})")
# Out:
# araria (अररिया)
# jokihat (जोकीहाट)
# palasi (पलासी)
# sikati (सिकटी)
# kursakanta (कुर्साकांटा)
# foribisgangen (फारिबिसगंज)
# raniganj (रानीगंज)
# narpatganj (नरपतगंज)
# bhargama (भरगामा)
# araval (अरवल)

# %% [markdown]
# ### Mouzas

# %%
df.mouza.nunique()
# Out:
# 26052

# %%
_df = df.drop_duplicates("mouza", ignore_index=True)
for i in range(10):
    mouza = _df.loc[i, "mouza"]
    english_translated = transliterate.hindi2english(mouza)
    print(f"{english_translated} ({mouza})")
# Out:
# phulwari (फुलवाड़ी)
# kismat jamua (किस्मत जमुआ)
# gilhwari (गिलहवाड़ी)
# khamgamaga (खमगढ़ा)
# jamua (जमुआ)
# sharanpur (शरणपुर)
# damada jagir (दमड़ा जागीर)
# dabhara (दभड़ा)
# tarabadi (ताराबाड़ी)
# jitwarpur (जितवारपुर)

# %% [markdown]
# ### Castes

# %%
# castes (top 25)
df_castes = (df
             .groupby('caste').size().reset_index()
             .rename_column(0, "count")
             .sort_values("count", ascending=False)
             .reset_index(drop=True)
            )

df_top25_castes = (df_castes
                   .head(25)
                   .assign(caste_eng=lambda df: df.caste.apply(transliterate.hindi2english))
                  )
print(f"Number of unique castes (from raw/uncleaned record) = {len(df_castes):,}")
df_top25_castes
# Out:
# Number of unique castes (from raw/uncleaned record) = 76,517
#                caste    count         caste_eng
# 0               यादव  4500844           yadavas
# 1             राजपुत  2151764            rajput
# 2           ब्राह्मण  1293878          brahmins
# 3             कुर्मी  1225727             kurmi
# 4                शेख  1039915             shekh
# 5               तेली   919487              teli
# 6            मुसलमान   818864           muslims
# 7            भूमिहार   780578          bhumihar
# 8            भुमिहार   753912          bhumihar
# 9             राजपूत   730700            rajput
# 10             कोइरी   657407             koiri
# 11             कोयरी   623744             coary
# 12             दुसाध   493008            dusadh
# 13              चमार   451610            chamar
# 14           ब्राहमण   427909          brahmins
# 15           ग्‍वाला   405472             guala
# 16             कोईरी   399645             koiri
# 17              अहीर   367962             aheer
# 18  भुमिहार ब्राह्मण   332422  bhumihar brahman
# 19            ग्वाला   326920             guala
# 20             धानुक   301590           dhaanuk
# 21                 -   282192
# 22           कुशवाहा   260403          kushwaha
# 23   भुमिहार ब्राहमण   232781  bhumihar brahman
# 24              कहार   208142             kahar

# %% [markdown]
# ### Zero & negative land areas

# %%
# 2,973,115 records with non-positive land areas
len(df.query("tt_area_acre<=0"))
# Out:
# 2973115

# %%
# 95,553 account holders with non-positive land areas
len(df.groupby("account_no")["tt_area_acre"].sum().reset_index().query("tt_area_acre<=0"))
# Out:
# 95553

# %%
# import winsound
# frequency = 2500  # Set Frequency To 2500 Hertz
# duration = 1000  # Set Duration To 1000 ms == 1 second
# winsound.Beep(frequency, duration)
