# %%
import pandas as pd
from pranaam import pranaam

FP_NAMES = '../data/ryot_hindi_caste.csv.gz'
df = pd.read_csv(FP_NAMES, compression="gzip")
assert 0==len(df[df.name_of_ryot.isna()])
df.head(3)
# Out:
# 2026-01-06 22:16:32.279450: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-06 22:16:32.385848: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-06 22:16:32.385961: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-06 22:16:32.386277: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
names = df.name_of_ryot.tolist()
result = pranaam.pred_rel(names, lang="hin")
result.to_csv('../data/hindi_names_religion.csv.gz', index=False, compression="gzip")
result.head(3)
# Out:
# 2026-01-06 22:16:39,180 - pranaam - INFO - Loading hin model from /home/lsys/land/venv_land/lib/python3.10/site-packages/pranaam/model/eng_and_hindi_models_v1/hin_model
# 2026-01-06 22:16:39.463243: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-06 22:16:39.500245: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-06 22:16:39.500753: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...

# %%
len(result)
# Out:
# 3193161
