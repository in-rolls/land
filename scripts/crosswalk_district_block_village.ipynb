# %%
import re
import pandas as pd

pd.set_option("display.max_columns", 50)
import janitor
import sidetable
from utilities.utils import get_fulldata

usecols = ["district", "division", "mouza"]
geo_slugs = ["zilla_district_lr", "anchal_block_lr", "mauja_village_lr"]


# Get Bihar land record data
df = (
    get_fulldata(**{"usecols": usecols})
    # ======================================================================
    # Renaming to the three geoslugs for consistency
    .rename_column("district", "zilla_district_lr")
    .rename_column("division", "anchal_block_lr")
    .rename_column("mouza", "mauja_village_lr")
    # ======================================================================
    # Make sure no whitespaces screw up the merge
    .assign(**{col: lambda df, k=col: df[k].str.strip() for col in geo_slugs})
    # ======================================================================
    # Get unique villages by the three geoslugs
    .drop_duplicates(geo_slugs)
    .reset_index(drop=True)
)
print(df.shape)
df.head()
# Out:
# /mnt/d/wsl-mnt/land/venv_land/lib/python3.10/site-packages/lazy_loader/__init__.py:185: RuntimeWarning: subpackages can technically be lazily loaded, but it causes the package to be eagerly loaded even if it is already lazily loaded.So, you probably shouldn't use subpackages with this lazy feature.
#   warnings.warn(msg, RuntimeWarning)
# /mnt/d/wsl-mnt/land/venv_land/lib/python3.10/site-packages/lazy_loader/__init__.py:185: RuntimeWarning: subpackages can technically be lazily loaded, but it causes the package to be eagerly loaded even if it is already lazily loaded.So, you probably shouldn't use subpackages with this lazy feature.
#   warnings.warn(msg, RuntimeWarning)
# (35628, 3)
#   zilla_district_lr anchal_block_lr mauja_village_lr
# 0            अररिया          अररिया          फुलवाड़ी
# 1            अररिया          अररिया      किस्मत जमुआ
# 2            अररिया          अररिया         गिलहवाड़ी
# 3            अररिया          अररिया            खमगढ़ा
# 4            अररिया          अररिया             जमुआ

# %%
# Tabulation of villages by 38 Bihar districts
df.stb.freq(["zilla_district_lr"])
# Out:
#    zilla_district_lr  count   percent  cumulative_count  cumulative_percent
# 0                गया   2833  7.951611              2833            7.951611
# 1             रोहतास   1905  5.346918              4738           13.298529
# 2         मुज़फ्फरपुर   1737  4.875379              6475           18.173908
# 3              बांका   1673  4.695745              8148           22.869653
# 4            भागलपुर   1642  4.608735              9790           27.478388
# 5              कैमूर   1618  4.541372             11408           32.019760
# 6             वैशाली   1503  4.218592             12911           36.238352
# 7           गोपालगंज   1472  4.131582             14383           40.369934
# 8               जमुई   1452  4.075446             15835           44.445380
# 9           औरंगाबाद   1439  4.038958             17274           48.484338
# 10         पूर्णियॉं   1224  3.435500             18498           51.919838
# 11            भोजपुर   1204  3.379365             19702           55.299203
# 12            दरभंगा   1184  3.323229             20886           58.622432
# 13              पटना   1105  3.101493             21991           61.723925
# 14             नवादा   1088  3.053778             23079           64.777703
# 15            नालंदा   1070  3.003256             24149           67.780959
# 16             बक्सर    928  2.604693             25077           70.385652
# 17            मधुबनी    840  2.357696             25917           72.743348
# 18     पश्चिम चंपारण    777  2.180869             26694           74.924217
# 19           सीतामढ़ी    752  2.110699             27446           77.034916
# 20            अररिया    735  2.062984             28181           79.097901
# 21           किशनगंज    732  2.054564             28913           81.152464
# 22            कटिहार    692  1.942293             29605           83.094757
# 23         समस्तीपुर    664  1.863703             30269           84.958460
# 24          बेगुसराए    652  1.830021             30921           86.788481
# 25            मुंगेर    626  1.757045             31547           88.545526
# 26          जहानाबाद    600  1.684069             32147           90.229595
# 27    पूर्वी चम्पारण    507  1.423038             32654           91.652633
# 28           लखीसराय    493  1.383743             33147           93.036376
# 29           मधेपुरा    438  1.229370             33585           94.265746
# 30              सारण    409  1.147974             33994           95.413720
# 31             सुपौल    371  1.041316             34365           96.455035
# 32           शेखपुरा    300  0.842034             34665           97.297070
# 33            खगड़िया    284  0.797126             34949           98.094196
# 34             सिवान    214  0.600651             35163           98.694847
# 35             शिवहर    205  0.575390             35368           99.270237
# 36             सहरसा    137  0.384529             35505           99.654766
# 37              अरवल    123  0.345234             35628          100.000000

# %%
# # Tabulation of villages by > 500 blocks
# # Will give 505 rows
# pd.set_option("display.max_rows", 505)
# df.stb.freq(["anchal_block_lr"])

# %%
# Get crosswalk data (from Aaditya)
df_xwalk = (
    pd.read_stata("../data/br_lr_census_crosswalk.dta")
    # ======================================================================
    # Remove the codes in brackets (e.g. जहानाबाद [001]' --> 'जहानाबाद')
    .assign(
        anchal_block_lr=lambda df: df["anchal_block_lr"].apply(
            lambda x: re.sub(r"\[.*?\]", "", x)
        )
    )
    # Make sure no whitespaces screw up the merge
    .assign(**{col: lambda df, k=col: df[k].str.strip() for col in geo_slugs})
    # ======================================================================
    # village is not the lowest geographical unit
    .drop_duplicates(geo_slugs)
    .reset_index(drop=True)
)
print(df_xwalk.shape)
df_xwalk.head()
# Out:
# (40957, 22)
#   zilla_district_lr  zilla_district_lr_code anumandal_subdiv_lr
# 0          जहानाबाद                      33            जहानाबाद  \
# 1          जहानाबाद                      33            जहानाबाद
# 2          जहानाबाद                      33            जहानाबाद
# 3          जहानाबाद                      33            जहानाबाद
# 4          जहानाबाद                      33            जहानाबाद
#
#    anumandal_subdiv_lr_code anchal_block_lr  anchal_circle_lr_code
# 0                         1        जहानाबाद                      1  \
# 1                         1        जहानाबाद                      1
# 2                         1        जहानाबाद                      1
# 3                         1        जहानाबाद                      1
# 4                         1        जहानाबाद                      1
#
#   mauja_village_lr revenue_station_no_lr  total_kasara_lr  total_accounts_lr
# 0            अंजनी                   407              235                182  \
# 1          अंजनीचक                   405               27                 19
# 2           अदलुचक                   381               92                 82
# 3             अमैन                   366              765                614
# 4             अरसठ                    28               14                  7
#
#   statecode_census statename_census districtcode_census districtname_census
# 0               10            BIHAR                 239          Jehanabad   \
# 1               10            BIHAR                 239          Jehanabad
# 2               10            BIHAR                 239          Jehanabad
# 3               10            BIHAR                 239          Jehanabad
# 4               10            BIHAR                 239          Jehanabad
#
#   subdistrictcode_census subdistrictname_census cdblockcode_census
# 0                  01536              Jehanabad               0524  \
# 1                  01536              Jehanabad               0524
# 2                  01536              Jehanabad               0524
# 3                  01536              Jehanabad               0524
# 4                  01536              Jehanabad               0524
#
#   cdblockname_census grampanchayatcode_census grampanchayatname_census
# 0          Jehanabad                     0003              Mandevigaha  \
# 1          Jehanabad                     0003              Mandevigaha
# 2          Jehanabad                     0010                   Pandui
# 3          Jehanabad                     0011                    Amain
# 4          Jehanabad                     0001   Surungapur Bhavanichak
#
#   villagecode_census villagename_census
# 0             260211             Anjani
# 1             260209         Anjanichak
# 2             260196           Adluchak
# 3             260182              Amain
# 4             260142             Arsath

# %%
# Attempt merge between Bihar data and the crosswalk
df_merged = (
    df.merge(df_xwalk, how="outer", on=geo_slugs, validate="1:1", indicator=True)
    .assign(_merge=lambda df_: df_["_merge"].map({"both": "both", "right_only": "Crosswalk only (file from Aaditya)", "left_only": "Bihar LR data only"}))
)
df_merged.head()
# Out:
# /mnt/d/wsl-mnt/land/venv_land/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1433: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
#   zilla_district_lr anchal_block_lr mauja_village_lr  zilla_district_lr_code
# 0            अररिया          अररिया          फुलवाड़ी                     7.0  \
# 1            अररिया          अररिया      किस्मत जमुआ                     7.0
# 2            अररिया          अररिया         गिलहवाड़ी                     7.0
# 3            अररिया          अररिया            खमगढ़ा                     7.0
# 4            अररिया          अररिया             जमुआ                     7.0
#
#   anumandal_subdiv_lr  anumandal_subdiv_lr_code  anchal_circle_lr_code
# 0              अररिया                       1.0                    1.0  \
# 1              अररिया                       1.0                    1.0
# 2              अररिया                       1.0                    1.0
# 3              अररिया                       1.0                    1.0
# 4              अररिया                       1.0                    1.0
#
#   revenue_station_no_lr  total_kasara_lr  total_accounts_lr statecode_census
# 0                   168           1147.0              828.0               10  \
# 1                   169            394.0              309.0               10
# 2                   170            704.0              383.0               10
# 3                   171           1450.0              802.0               10
# 4                   172           2498.0             1829.0               10
#
#   statename_census districtcode_census districtname_census
# 0            BIHAR                 209              Araria  \
# 1            BIHAR                 209              Araria
# 2            BIHAR                 209              Araria
# 3            BIHAR                 209              Araria
# 4            BIHAR                 209              Araria
#
#   subdistrictcode_census subdistrictname_census cdblockcode_census
# 0                  01116                 Araria               0104  \
# 1                  01116                 Araria               0104
# 2                  01116                 Araria               0104
# 3                  01116                 Araria               0104
# 4                  01116                 Araria               0104
#
#   cdblockname_census grampanchayatcode_census grampanchayatname_census
# 0             Araria                     0002                    Jamua  \
# 1             Araria                     0002                    Jamua
# 2             Araria                     0005         Kismat Khawaspur
# 3             Araria                     0002                    Jamua
# 4             Araria                     0002                    Jamua
#
#   villagecode_census villagename_census _merge
# 0             221808           Phulbari   both
# 1             221809       Kismat Jamua   both
# 2             221810          Gelhabari   both
# 3             221811           Khamgara   both
# 4             221812              Jamua   both

# %%
df_merged.stb.freq(["_merge"], style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5a507">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a507_level0_col0" class="col_heading level0 col0" >_merge</th>
#       <th id="T_5a507_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_5a507_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_5a507_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_5a507_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a507_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a507_row0_col0" class="data row0 col0" >both</td>
#       <td id="T_5a507_row0_col1" class="data row0 col1" >27,720</td>
#       <td id="T_5a507_row0_col2" class="data row0 col2" >56.73%</td>
#       <td id="T_5a507_row0_col3" class="data row0 col3" >27,720</td>
#       <td id="T_5a507_row0_col4" class="data row0 col4" >56.73%</td>
#     </tr>
#     <tr>
#       <th id="T_5a507_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a507_row1_col0" class="data row1 col0" >Crosswalk only (file from Aaditya)</td>
#       <td id="T_5a507_row1_col1" class="data row1 col1" >13,237</td>
#       <td id="T_5a507_row1_col2" class="data row1 col2" >27.09%</td>
#       <td id="T_5a507_row1_col3" class="data row1 col3" >40,957</td>
#       <td id="T_5a507_row1_col4" class="data row1 col4" >83.82%</td>
#     </tr>
#     <tr>
#       <th id="T_5a507_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a507_row2_col0" class="data row2 col0" >Bihar LR data only</td>
#       <td id="T_5a507_row2_col1" class="data row2 col1" >7,908</td>
#       <td id="T_5a507_row2_col2" class="data row2 col2" >16.18%</td>
#       <td id="T_5a507_row2_col3" class="data row2 col3" >48,865</td>
#       <td id="T_5a507_row2_col4" class="data row2 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 7.9k (district, block, village) tuples appear only in the Bihar land record table (left table)
df_merged.query("_merge=='Bihar LR data only'")
# Out:
# /mnt/d/wsl-mnt/land/venv_land/lib/python3.10/site-packages/pandas/core/algorithms.py:535: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   common = np.find_common_type([values.dtype, comps_array.dtype], [])
#       zilla_district_lr anchal_block_lr             mauja_village_lr
# 1421           औरंगाबाद       कुटुम्‍बा            खैरा नोनिया बिगहा  \
# 3978              कैमूर            भभुआ                      करमी चक
# 3980              कैमूर            भभुआ                   खैरा खूर्द
# 3987              कैमूर            भभुआ                   औरंईया देव
# 6021                गया             नगर         नगरपालिका वार्ड न0-2
# ...                 ...             ...                          ...
# 33508         समस्तीपुर          हसनपुर  नरपतपुर नगर उर्फ चन्‍द्रपुर
# 33661         समस्तीपुर         सिंघिया              खराजी लक्षमनियॉ
# 33963              सारण            छपरा                    बाजित पुर
# 34024              सारण        बनियापुर                  छतवॉं खुर्द
# 34129              सारण        रिविलगंज            दक्षिणवारी चक्किी
#
#        zilla_district_lr_code anumandal_subdiv_lr  anumandal_subdiv_lr_code
# 1421                      NaN                 NaN                       NaN  \
# 3978                      NaN                 NaN                       NaN
# 3980                      NaN                 NaN                       NaN
# 3987                      NaN                 NaN                       NaN
# 6021                      NaN                 NaN                       NaN
# ...                       ...                 ...                       ...
# 33508                     NaN                 NaN                       NaN
# 33661                     NaN                 NaN                       NaN
# 33963                     NaN                 NaN                       NaN
# 34024                     NaN                 NaN                       NaN
# 34129                     NaN                 NaN                       NaN
#
#        anchal_circle_lr_code revenue_station_no_lr  total_kasara_lr
# 1421                     NaN                   NaN              NaN  \
# 3978                     NaN                   NaN              NaN
# 3980                     NaN                   NaN              NaN
# 3987                     NaN                   NaN              NaN
# 6021                     NaN                   NaN              NaN
# ...                      ...                   ...              ...
# 33508                    NaN                   NaN              NaN
# 33661                    NaN                   NaN              NaN
# 33963                    NaN                   NaN              NaN
# 34024                    NaN                   NaN              NaN
# 34129                    NaN                   NaN              NaN
#
#        total_accounts_lr statecode_census statename_census
# 1421                 NaN              NaN              NaN  \
# 3978                 NaN              NaN              NaN
# 3980                 NaN              NaN              NaN
# 3987                 NaN              NaN              NaN
# 6021                 NaN              NaN              NaN
# ...                  ...              ...              ...
# 33508                NaN              NaN              NaN
# 33661                NaN              NaN              NaN
# 33963                NaN              NaN              NaN
# 34024                NaN              NaN              NaN
# 34129                NaN              NaN              NaN
#
#       districtcode_census districtname_census subdistrictcode_census
# 1421                  NaN                 NaN                    NaN  \
# 3978                  NaN                 NaN                    NaN
# 3980                  NaN                 NaN                    NaN
# 3987                  NaN                 NaN                    NaN
# 6021                  NaN                 NaN                    NaN
# ...                   ...                 ...                    ...
# 33508                 NaN                 NaN                    NaN
# 33661                 NaN                 NaN                    NaN
# 33963                 NaN                 NaN                    NaN
# 34024                 NaN                 NaN                    NaN
# 34129                 NaN                 NaN                    NaN
#
#       subdistrictname_census cdblockcode_census cdblockname_census
# 1421                     NaN                NaN                NaN  \
# 3978                     NaN                NaN                NaN
# 3980                     NaN                NaN                NaN
# 3987                     NaN                NaN                NaN
# 6021                     NaN                NaN                NaN
# ...                      ...                ...                ...
# 33508                    NaN                NaN                NaN
# 33661                    NaN                NaN                NaN
# 33963                    NaN                NaN                NaN
# 34024                    NaN                NaN                NaN
# 34129                    NaN                NaN                NaN
#
#       grampanchayatcode_census grampanchayatname_census villagecode_census
# 1421                       NaN                      NaN                NaN  \
# 3978                       NaN                      NaN                NaN
# 3980                       NaN                      NaN                NaN
# 3987                       NaN                      NaN                NaN
# 6021                       NaN                      NaN                NaN
# ...                        ...                      ...                ...
# 33508                      NaN                      NaN                NaN
# 33661                      NaN                      NaN                NaN
# 33963                      NaN                      NaN                NaN
# 34024                      NaN                      NaN                NaN
# 34129                      NaN                      NaN                NaN
#
#       villagename_census              _merge
# 1421                 NaN  Bihar LR data only
# 3978                 NaN  Bihar LR data only
# 3980                 NaN  Bihar LR data only
# 3987                 NaN  Bihar LR data only
# 6021                 NaN  Bihar LR data only
# ...                  ...                 ...
# 33508                NaN  Bihar LR data only
# 33661                NaN  Bihar LR data only
# 33963                NaN  Bihar LR data only
# 34024                NaN  Bihar LR data only
# 34129                NaN  Bihar LR data only
#
# [7908 rows x 23 columns]

# %%
"नगरपालीका वार्ड0 10" in df_xwalk.mauja_village_lr.unique()
# Out:
# False

# %%
"नगरपालीका वार्ड0" in df_xwalk.mauja_village_lr.unique()
# Out:
# False

# %%
"नगरपालीका वार्ड" in df_xwalk.mauja_village_lr.unique()
# Out:
# False
