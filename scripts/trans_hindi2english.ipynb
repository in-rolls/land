# %%
from indicate import transliterate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from indicate import transliterate
#
# File D:\ProgramData\Anaconda3\lib\site-packages\indicate\__init__.py:1, in <module>
# ----> 1 from .transliterate import hindi2english
#       3 __all__ = ["hindi2english"]
#
# File D:\ProgramData\Anaconda3\lib\site-packages\indicate\transliterate.py:4, in <module>
#       1 import sys
#       2 import argparse
# ----> 4 from .hindi2english import HindiToEnglish
#       6 hindi2english = HindiToEnglish.transliterate
#       9 def main(argv=sys.argv[1:]):
#
# File D:\ProgramData\Anaconda3\lib\site-packages\indicate\hindi2english.py:24, in <module>
#      20     raise TimeoutException("Timeout!", "")
#      23 # Change the behavior of SIGALRM
# ---> 24 signal.signal(signal.SIGALRM, timeout_handler)
#      27 class HindiToEnglish(Base):
#      28     MODELFN = "data/model/hindi_to_english/saved_weights/"
#
# AttributeError: module 'signal' has no attribute 'SIGALRM'

# %%
english_translated = transliterate.hindi2english("हिंदी")
print(english_translated)

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
# Out:
# D:\ProgramData\Anaconda3\python.exe
# 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# sys.version_info(major=3, minor=9, micro=12, releaselevel='final', serial=0)
